# %%
import itertools
import pickle
import numpy as np
from numba import jit

# %%
batch_size = 1024
num_validation_batches = 32
num_agents = 4
prob = 0.2

np.random.seed(42)

# %% [markdown]
# # Generating Data

# %%
def generate_permutation_array(N, num_agents):
    P = np.zeros((N, num_agents))
    for i in range(N):
        P[i] = np.random.permutation(num_agents)
    return P


class Data(object):
    """
    A class for generating data for the matching problem
    """
    def __init__(self, num_agents, prob, corr):
        self.num_agents = num_agents
        self.prob = prob
        self.corr = corr


    def sample_ranking(self, N, prob):
        """
        Samples ranked lists
        Arguments
            N: Number of samples
            prob: Probability of truncation
        Returns:
            Ranked List of shape [N, Num_agents]
        """
        N_trunc = int(N * prob)
        P = generate_permutation_array(N, self.num_agents) + 1

        if N_trunc > 0:
            # Choose indices to truncate
            idx = np.random.choice(N, N_trunc, replace = False)

            # Choose a position to truncate
            trunc = np.random.randint(self.num_agents, size = N_trunc)

            # Normalize so preference to remain single has 0 payoff
            swap_vals = P[idx, trunc]
            P[idx, trunc] = 0
            P[idx] = P[idx] - swap_vals[:, np.newaxis]

        return P/self.num_agents


    def generate_all_ranking(self, include_truncation = True):
        """
        Generates all possible rankings
        Arguments
            include_truncation: Whether to include truncations or only generate complete rankings
        Returns:
            Ranked of list of shape: [m, num_agents]
                where m = N! if complete, (N+1)! if truncations are included
        """
        if include_truncation is False:
            M = np.array(list(itertools.permutations(np.arange(self.num_agents)))) + 1.0
        else:
            M = np.array(list(itertools.permutations(np.arange(self.num_agents + 1))))
            M = (M - M[:, -1:])[:, :-1]

        return M/self.num_agents


    def generate_batch(self, batch_size, prob = None, corr = None):
        """
        Samples a batch of data from training
        Arguments
            batch_size: number of samples
            prob: probability of truncation
        Returns
            P: Men's preferences,
                P_{ij}: How much Man-i prefers to be Women-j
            Q: Women's preferences,
                Q_{ij}: How much Woman-j prefers to be with Man-i
        """
        if corr is None: corr = self.corr
        if prob is None: prob = self.prob

        N = batch_size * self.num_agents

        P = self.sample_ranking(N, prob)
        Q = self.sample_ranking(N, prob)

        P = P.reshape(-1, self.num_agents, self.num_agents)
        Q = Q.reshape(-1, self.num_agents, self.num_agents)

        if corr > 0.00:
            P_common = self.sample_ranking(batch_size, prob).reshape(batch_size, 1, self.num_agents)
            Q_common = self.sample_ranking(batch_size, prob).reshape(batch_size, 1, self.num_agents)

            P_idx = np.random.binomial(1, corr, [batch_size, self.num_agents, 1])
            Q_idx = np.random.binomial(1, corr, [batch_size, self.num_agents, 1])

            P = P * (1 - P_idx) + P_common * P_idx
            Q = Q * (1 - Q_idx) + Q_common * Q_idx

        Q = Q.transpose(0, 2, 1)

        return P, Q


    def compose_misreport(self, P, Q, M, agent_idx, is_P = True):
        """ Composes mis-report
        Arguments:
            P: Men's preference, [Batch_size, num_agents, num_agents]
            Q: Women's preference [Batch_size, num_agents, num_agents]
            M: Ranked List of mis_reports
                    either [num_misreports, num_agents]
                    or [batch_size, num_misreports, num_agents]
            agent_idx: Agent-idx that is mis-reporting
            is_P: if True, Men[agent-idx] misreporting
                    else, Women[agent-idx] misreporting

        Returns:
            P_mis, Q_mis: [batch-size, num_misreports, num_agents, num_agents]

        """
        num_misreports = M.shape[-2]
        P_mis = np.tile(P[:, None, :, :], [1, num_misreports, 1, 1])
        Q_mis = np.tile(Q[:, None, :, :], [1, num_misreports, 1, 1])

        if is_P: P_mis[:, :, agent_idx, :] = M
        else: Q_mis[:, :, :, agent_idx] = M

        return P_mis, Q_mis


    def generate_all_misreports(self, P, Q, agent_idx, is_P, include_truncation = True):
        """ Generates all mis-reports
        Arguments:
            P: Men's preference, [Batch_size, num_agents, num_agents]
            Q: Women's preference [Batch_size, num_agents, num_agents]
            agent_idx: Agent-idx that is mis-reporting
            is_P: if True, Men[agent-idx] misreporting
                    else, Women[agent-idx] misreporting
            include_truncation: Whether to truncate preference or submit complete preferences

        Returns:
            P_mis, Q_mis: [batch-size, M, num_agents, num_agents]
                where M = (num_agents + 1)! if truncations are includes
                      M = (num_agents)! if preferences are complete
        """
        M = self.generate_all_ranking(include_truncation = include_truncation)
        P_mis, Q_mis = self.compose_misreport(P, Q, M, agent_idx, is_P)

        return P_mis, Q_mis


    def sample_misreports(self, P, Q, num_misreports_per_sample, agent_idx, is_P, prob = None):
        """ Samples misreports
        Arguments:
            P: Men's preference, [Batch_size, num_agents, num_agents]
            Q: Women's preference [Batch_size, num_agents, num_agents]
            num_misreports_per_sample: Number of misreports per sample
            agent_idx: Agent-idx that is mis-reporting
            is_P: if True, Men[agent-idx] misreporting
                    else, Women[agent-idx] misreporting
            prob: probability of truncation

        Returns:
            P_mis, Q_mis: [batch-size, num_misreports_per_sample, num_agents, num_agents]
        """
        if prob is None: prob = self.prob

        N = P.shape[0]
        M = self.sample_ranking(N * num_misreports_per_sample, prob).reshape(N, num_misreports_per_sample, -1)
        P_mis, Q_mis = self.compose_misreport(P, Q, M, agent_idx, is_P)

        return P_mis, Q_mis

# %% [markdown]
# # Loss Function

# %%
# Loss functions numpy
def STABILITY_VIOLATION_BATCH(P, Q, R):
    WP = np.maximum(P[:, :, np.newaxis, :] - P[:, :, :, np.newaxis], 0)
    WQ = np.maximum(Q[:, :, np.newaxis, :] - Q[:, np.newaxis, :, :], 0)   
       
    T = (1 - np.sum(R, axis = 1, keepdims = True))
    S = (1 - np.sum(R, axis = 2, keepdims = True))
    
    RGT_1 = np.einsum('bjc,bijc->bic', R, WQ) + T * np.maximum(Q, 0)
    RGT_2 = np.einsum('bia,biac->bic', R, WP) + S * np.maximum(P, 0)
    
    REGRET =  RGT_1 * RGT_2 
    
    return REGRET.sum(-1).sum(-1).mean()/num_agents



def IR_VIOLATION_BATCH(P, Q, R):
    IR_1 = R * np.maximum(-Q, 0)
    IR_2 = R * np.maximum(-P, 0)
    IR = IR_1 + IR_2
    
    return IR.sum(-1).sum(-1).mean()/num_agents



def IC_FOSD_VIOLATION_BATCH(P, Q, R, mechanism, data_generator, r_mult = 1.0):
    
    IC_viol_P = np.zeros(num_agents)
    IC_viol_Q = np.zeros(num_agents)
    
    discount = r_mult ** np.arange(num_agents)
    
    for agent_idx in range(num_agents):
        P_mis, Q_mis = data_generator.generate_all_misreports(P, Q, agent_idx = agent_idx, is_P = True, include_truncation = True)
        R_mis = mechanism(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis = R_mis.reshape(batch_size, -1, num_agents, num_agents)

        
        R_diff = (R_mis[:, :, agent_idx, :] - R[:, None, agent_idx, :])*(P[:, None, agent_idx, :] > 0)
        IDX = np.argsort(-P[:, agent_idx, :])
        IDX = np.tile(IDX[:, None, :], (1, R_mis.shape[1], 1))
        
        FOSD_viol = np.cumsum(np.take_along_axis(R_diff, IDX, axis=-1) * discount, -1)
        IC_viol_P[agent_idx] = np.maximum(FOSD_viol, 0).max(-1).max(-1).mean(-1)
        
        P_mis, Q_mis = data_generator.generate_all_misreports(P, Q, agent_idx = agent_idx, is_P = False, include_truncation = True)
        R_mis = mechanism(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis = R_mis.reshape(batch_size, -1, num_agents, num_agents)

        R_diff = (R_mis[:, :, :, agent_idx] - R[:, None, :, agent_idx]) * (Q[:, None, :, agent_idx] > 0)
        IDX = np.argsort(-Q[:, :, agent_idx])
        IDX = np.tile(IDX[:, None, :], (1, R_mis.shape[1], 1))
        
        FOSD_viol = np.cumsum(np.take_along_axis(R_diff, IDX, axis=-1) * discount, -1)
        IC_viol_Q[agent_idx] = np.maximum(FOSD_viol, 0).max(-1).max(-1).mean(-1)
        
    IC_viol = (IC_viol_P.mean() + IC_viol_Q.mean()) * 0.5
    
    return IC_viol

# %% [markdown]
# # Classical Methods

# %%
@jit(nopython=True)
def get_DA(P, Q, menPreferences, womenPreferences):
    
    num_instances, num_agents = P.shape[0], P.shape[1]
    R = np.zeros(P.shape)
    
    for inst in range(num_instances):
        # Start with no married men
        unmarriedMen = list(range(num_agents))
        
        # No Spouse Yet
        manSpouse, womanSpouse = [-1] * num_agents, [-1] * num_agents
        
        # Ptr to index of top choice
        nextManchoice = [0] * num_agents
        
        while unmarriedMen:
            he = unmarriedMen[0] 
            
            # He is out of choices, single    
            if nextManchoice[he] == num_agents: 
                manSpouse[he] = num_agents
                unmarriedMen.pop(0)
                continue
                
            she = menPreferences[inst, he, nextManchoice[he]]
            
            # He prefers being single than his top choice: Stay single
            if P[inst, he, she] < 0:
                manSpouse[he] = num_agents
                unmarriedMen.pop(0)
                continue
                            
            # Top Choice is not Married
            if womanSpouse[she] == -1:  
                # She prefers being married rather than being single, so she accepts
                if Q[inst, he, she] > 0: 
                    womanSpouse[she], manSpouse[he] = he, she
                    R[inst, he, she] = 1
                    unmarriedMen.pop(0)
            else:
                # She prefers this man over her current husband, break-up, accept proposal  
                currentHusband = womanSpouse[she]
                if Q[inst, he, she] > Q[inst, currentHusband, she]:
                    womanSpouse[she], manSpouse[he] = he, she
                    R[inst, he, she] = 1
                    R[inst, currentHusband, she] = 0                    
                    unmarriedMen[0] = currentHusband

            nextManchoice[he] = nextManchoice[he] + 1
            
    return R

# %%
@jit(nopython=True)
def get_SD(P, Q, menPreferences, womenPreferences, order):    
    num_instances, num_agents = P.shape[0], P.shape[1]  
    R = np.zeros(P.shape)
    
    for inst in range(num_instances):
        manSpouse, womanSpouse = [-1] * num_agents, [-1] * num_agents
                
        for agent in order:
            # MAN
            if agent < num_agents:
                he = agent
                
                # Already taken: skip
                if not manSpouse[he] == -1: continue
                
                # Iterate over his top choices
                for she in menPreferences[inst, he]:
                    
                    # Current Top Choice less preferred than being single
                    if P[inst, he, she] < 0: break
                        
                    # His top-choice is not already taken, then marry
                    if womanSpouse[she] == -1:
                        manSpouse[he], womanSpouse[she] = she, he
                        R[inst, he, she] = 1
                        break
                        
                # If no assignments worked out, he is single
                if manSpouse[he] == -1: manSpouse[he] = num_agents
                    
            # WOMAN
            else:
                she = agent - num_agents
                
                # Already taken: skip
                if not womanSpouse[she] == -1: continue
                    
                # Iterate over her top choices
                for he in womenPreferences[inst, :, she]:
                   
                    # Current Top Choice less preferred than being single
                    if Q[inst, he, she] < 0: break
                        
                    # Her top-choice is not already taken, then marry
                    if manSpouse[he] == -1:
                        manSpouse[he], womanSpouse[she] = she, he
                        R[inst, he, she] = 1
                        break
                    
                # If no assignments worked out, she is single
                if womanSpouse[she] == -1: womanSpouse[she] = num_agents
                
    return R

# %%
@jit(nopython=True)
def get_RSD(P, Q, menPreferences, womenPreferences, orders):    
    num_instances, num_agents = P.shape[0], P.shape[1]  
    R = np.zeros(P.shape)
    
    for inst in range(num_instances):
           
        for order in orders:
            
            manSpouse, womanSpouse = [-1] * num_agents, [-1] * num_agents
        
            for agent in order:

                # MAN
                if agent < num_agents:
                    he = agent

                    # Already taken: skip
                    if not manSpouse[he] == -1: continue

                    # Iterate over his top choices
                    for she in menPreferences[inst, he]:

                        # Current Top Choice less preferred than being single
                        if P[inst, he, she] < 0: break

                        # His top-choice is not already taken, then marry
                        if womanSpouse[she] == -1:
                            manSpouse[he], womanSpouse[she] = she, he
                            R[inst, he, she] += 1
                            break

                    # If no assignments worked out, he is single
                    if manSpouse[he] == -1: manSpouse[he] = num_agents

                # WOMAN
                else:
                    she = agent - num_agents

                    # Already taken: skip
                    if not womanSpouse[she] == -1: continue

                    # Iterate over her top choices
                    for he in womenPreferences[inst, :, she]:

                        # Current Top Choice less preferred than being single
                        if Q[inst, he, she] < 0: break

                        # Her top-choice is not already taken, then marry
                        if manSpouse[he] == -1:
                            manSpouse[he], womanSpouse[she] = she, he
                            R[inst, he, she] += 1
                            break

                    # If no assignments worked out, she is single
                    if womanSpouse[she] == -1: womanSpouse[she] = num_agents
                
    return R/orders.shape[0]

# %%
@jit(nopython=True)
def get_one_RSD(P, Q, menPreferences, womenPreferences, orders):    
    num_instances, num_agents = P.shape[0], P.shape[1]  
    R = np.zeros(P.shape)
    
    for inst in range(num_instances):           
        for order in orders:
            womanSpouse = [-1] * num_agents
            for he in order:
                
                # Iterate over his top choices
                for she in menPreferences[inst, he]:
                    
                    # Current Top Choice less preferred than being single
                    if P[inst, he, she] < 0: break
                    
                    # His top-choice is not already taken, then marry
                    if womanSpouse[she] == -1:
                        womanSpouse[she] = he
                        R[inst, he, she] += 1
                        break
                        
    return R/orders.shape[0]

# %%
@jit(nopython=True)
def get_TTC(P, Q, menPreferences, womenPreferences): 
         
    num_instances, num_agents = P.shape[0], P.shape[1]
    R = np.zeros(P.shape)
    
    for inst in range(num_instances):        
        matched = [0] * (2 * num_agents)
        for rnd in range(2 * num_agents): 
            # Create graph              
            G = np.arange(2 * num_agents)    
            for agent in range(2*num_agents):
                if matched[agent] == 1: 
                    G[agent] = -1
                    continue
                                
                # Men Processing
                if agent < num_agents:                   
                    he = agent
                    # Iterate through his preferences
                    for she in menPreferences[inst, he]:
                        
                        # If top available choice is unacceptable, self-point
                        if P[inst, he, she] < 0: break

                        # If top choice is is acceptable and unmatched, point
                        if matched[num_agents + she] == 0:
                            G[he] = num_agents + she
                            break
                            
                else:                   
                    she = agent - num_agents
                    # Iterate through her preferences
                    for he in womenPreferences[inst, :, she]:
                        # If top available choice is unacceptable, self-point
                        if Q[inst, he, she] < 0:  break

                        # If top choice is is acceptable and unmatched, point
                        if matched[he] == 0:
                            G[num_agents + she] = he
                            break
                        
            #print(G)
            # Pick the first unmatched man.   
            curr = -1
            for agent in range(num_agents):
                if matched[agent] == 0:
                    curr = agent
                    break
            
            # If every man is matched, exit    
            if curr == -1: break

            # Find head of a cycle
            visited = [0] * (2 * num_agents)  
            while not visited[curr] == 1:
                visited[curr] = 1
                curr = G[curr]

            # If it's a self point, match and continue with next round
            if curr == G[curr]: 
                matched[curr] = 1
                continue
            
            # Make sure to start with a manc//man-proposing
            if curr >= num_agents: 
                curr = G[curr]

            visited = [0] * (2 * num_agents)  
            # Do matching and exit
            while not visited[curr] == 1:
                R[inst, curr, G[curr] - num_agents] = 1
                matched[curr], matched[G[curr]] = 1, 1
                visited[curr], visited[G[curr]] = 1, 1
                curr = G[G[curr]]
                
    return R

# %%
# Worker Proposing
# Serial Dictatorship
def compute_SD_batch(P, Q):
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    order = np.arange(2 * P.shape[1])
    return get_SD(P, Q, menPreferences, womenPreferences, order)

# Firm Proposing
# Serial Dictatorship
def compute_SD_batch_switch(P, Q):
    P, Q = Q.transpose((0, 2, 1)), P.transpose((0, 2, 1))
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    order = np.arange(2 * P.shape[1])
    return get_SD(P, Q, menPreferences, womenPreferences, order).transpose(0, 2, 1)

# %%
# Worker-Proposing RSD
def compute_one_RSD_batch(P, Q):
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    orders = np.array(list(itertools.permutations(list(range(P.shape[1])))))
    return get_RSD(P, Q, menPreferences, womenPreferences, orders)

# Firm-Proposing RSD
def compute_one_RSD_batch_switch(P, Q):
    P, Q = Q.transpose((0, 2, 1)), P.transpose((0, 2, 1))
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    orders = np.array(list(itertools.permutations(list(range(P.shape[1])))))
    return get_RSD(P, Q, menPreferences, womenPreferences, orders).transpose(0, 2, 1)

# %%
# Worker-Proposing TTC
def compute_TTC_batch(P, Q):
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    return get_TTC(P, Q, menPreferences, womenPreferences)

# Firm-Proposing TTC
def compute_TTC_batch_switch(P, Q):
    P, Q = Q.transpose((0, 2, 1)), P.transpose((0, 2, 1))
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    return get_TTC(P, Q, menPreferences, womenPreferences).transpose(0, 2, 1)

# %%
# Worker-Proposing DA
def compute_DA_batch(P, Q):
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    return get_DA(P, Q, menPreferences, womenPreferences)

# Firm-Proposing DA
def compute_DA_batch_switch(P, Q):
    P, Q = Q.transpose((0, 2, 1)), P.transpose((0, 2, 1))
    menPreferences = np.argsort(-P, axis = -1)
    womenPreferences = np.argsort(-Q, axis = -2)
    return get_DA(P, Q, menPreferences, womenPreferences).transpose(0, 2, 1)

# %%
def compute_violations(mech, corr):
    VAL_ST_LOSS = 0.0
    VAL_IC_LOSS = 0.0
    
    data_generator = Data(num_agents = num_agents, prob = prob, corr = corr)

    for j in range(num_validation_batches):
        P, Q = data_generator.generate_batch(batch_size)
        R = mech(P, Q)

        ST_LOSS = STABILITY_VIOLATION_BATCH(P, Q, R) + IR_VIOLATION_BATCH(P, Q, R)
        IC_LOSS = IC_FOSD_VIOLATION_BATCH(P, Q, R, mech, data_generator)
        VAL_ST_LOSS += ST_LOSS
        VAL_IC_LOSS += IC_LOSS

        print("[Batch]: %d, [ST-Loss]: %f, [IC-Loss]: %f"%(j, ST_LOSS, IC_LOSS))
        
    VAL_ST_LOSS = VAL_ST_LOSS/num_validation_batches
    VAL_IC_LOSS = VAL_IC_LOSS/num_validation_batches
    print("\t[ST-Loss]: %f, [IC-Loss]: %f"%(VAL_ST_LOSS, VAL_IC_LOSS))
    
    return VAL_ST_LOSS, VAL_IC_LOSS

# %% [markdown]
# # Computing ST, IC

# %%
corr_values = [0.0, 0.25, 0.50, 0.75]

DA_ST_corrs = []
DA_IC_corrs = []

for corr in corr_values:
    mech = compute_DA_batch
    s1, i1 = compute_violations(mech, corr)
    
    mech = compute_DA_batch_switch
    s2, i2 = compute_violations(mech, corr)
    
    DA_ST_corrs.append(max(s1, s2))
    DA_IC_corrs.append(max(i1, i2))
    
    print("[Correlation] = %f, [DA_ST] = %f, [DA_IC] = %f\n\n"%(corr, DA_ST_corrs[-1], DA_IC_corrs[-1]))
# Out:
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.053101
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.054443
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.052734
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.054199
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.051270
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.061035
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.056030
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.052734
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.055176
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.056763
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.054932
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.056152
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.049072
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.049927
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.057617
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.061768
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.055908
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.053467
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.055420
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.053345
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.053955
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.057007
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.056763
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.058960
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.055176
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.054688
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.057983
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.062744
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.057373
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.051514
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.054810
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.057373
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.055420
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.055298
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.057129
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.055786
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.055786
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.056152
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.064331
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.056519
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.055908
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.053345
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.050903
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.057983
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.058228
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.051636
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.055908
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.053955
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.049072
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.058228
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.055664
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.056641
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.057251
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.060425
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.056519
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.056519
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.052856
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.057983
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.062988
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.057007
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.049805
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.060059
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.063110
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.055054
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.050537
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.056206
# [Correlation] = 0.000000, [DA_ST] = 0.000000, [DA_IC] = 0.056206
#
#
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.043579
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.048584
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.048706
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.046875
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.043213
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.047485
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.047363
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.047363
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.051514
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.039551
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.051514
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.050659
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.041992
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.048340
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.047607
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.051147
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.049316
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.045654
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.049316
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.045288
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.044312
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.052002
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.049561
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.052368
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.043701
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.045166
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.047485
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.049927
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.051147
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.052612
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.053223
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.046631
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.047913
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.047729
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.037354
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.042480
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.050293
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.046265
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.046509
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.048462
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.048218
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.052246
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.047241
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.051514
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.047241
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.051880
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.046509
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.050171
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.044434
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.043945
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.046997
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.047241
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.050781
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.051392
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.047119
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.050537
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.048218
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.051880
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.046631
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.049805
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.046997
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.040771
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.047485
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.044922
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.047852
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.047535
# [Correlation] = 0.250000, [DA_ST] = 0.000000, [DA_IC] = 0.047913
#
#
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.028442
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.026978
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.028564
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.029907
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.026367
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.028687
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.025757
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.026978
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.025635
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.030518
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.026978
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.027466
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.026978
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.027954
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.028809
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.029297
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.030396
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.026489
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.028931
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.027954
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.024536
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.030151
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.025757
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.025757
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.028198
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.024536
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.025269
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.027466
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.028442
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.029541
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.026123
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.024658
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.027485
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.027954
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.027344
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.026245
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.030029
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.027466
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.029419
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.029541
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.027954
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.026611
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.030029
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.028076
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.024902
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.028320
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.027832
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.030029
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.031250
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.030884
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.025391
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.025024
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.032715
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.027466
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.029175
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.031128
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.029663
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.027954
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.027588
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.025146
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.030640
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.028931
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.025879
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.030029
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.028076
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.028397
# [Correlation] = 0.500000, [DA_ST] = 0.000000, [DA_IC] = 0.028397
#
#
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.009521
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.007324
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.007935
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.009766
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.005127
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.010742
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.010010
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.006104
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.008911
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.009155
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.010620
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.008789
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.007080
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.008179
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.009155
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.010498
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.005737
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.012451
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.007568
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.008911
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.007080
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.012573
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.010498
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.007935
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.008545
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.012207
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.009277
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.009277
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.009766
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.010132
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.009766
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.010864
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.009109
# [Batch]: 0, [ST-Loss]: 0.000000, [IC-Loss]: 0.007812
# [Batch]: 1, [ST-Loss]: 0.000000, [IC-Loss]: 0.007568
# [Batch]: 2, [ST-Loss]: 0.000000, [IC-Loss]: 0.009521
# [Batch]: 3, [ST-Loss]: 0.000000, [IC-Loss]: 0.009644
# [Batch]: 4, [ST-Loss]: 0.000000, [IC-Loss]: 0.005371
# [Batch]: 5, [ST-Loss]: 0.000000, [IC-Loss]: 0.009888
# [Batch]: 6, [ST-Loss]: 0.000000, [IC-Loss]: 0.005249
# [Batch]: 7, [ST-Loss]: 0.000000, [IC-Loss]: 0.009277
# [Batch]: 8, [ST-Loss]: 0.000000, [IC-Loss]: 0.010010
# [Batch]: 9, [ST-Loss]: 0.000000, [IC-Loss]: 0.009033
# [Batch]: 10, [ST-Loss]: 0.000000, [IC-Loss]: 0.009155
# [Batch]: 11, [ST-Loss]: 0.000000, [IC-Loss]: 0.010010
# [Batch]: 12, [ST-Loss]: 0.000000, [IC-Loss]: 0.006104
# [Batch]: 13, [ST-Loss]: 0.000000, [IC-Loss]: 0.009155
# [Batch]: 14, [ST-Loss]: 0.000000, [IC-Loss]: 0.009155
# [Batch]: 15, [ST-Loss]: 0.000000, [IC-Loss]: 0.007324
# [Batch]: 16, [ST-Loss]: 0.000000, [IC-Loss]: 0.006714
# [Batch]: 17, [ST-Loss]: 0.000000, [IC-Loss]: 0.010132
# [Batch]: 18, [ST-Loss]: 0.000000, [IC-Loss]: 0.006226
# [Batch]: 19, [ST-Loss]: 0.000000, [IC-Loss]: 0.008911
# [Batch]: 20, [ST-Loss]: 0.000000, [IC-Loss]: 0.010742
# [Batch]: 21, [ST-Loss]: 0.000000, [IC-Loss]: 0.007935
# [Batch]: 22, [ST-Loss]: 0.000000, [IC-Loss]: 0.012939
# [Batch]: 23, [ST-Loss]: 0.000000, [IC-Loss]: 0.008789
# [Batch]: 24, [ST-Loss]: 0.000000, [IC-Loss]: 0.008667
# [Batch]: 25, [ST-Loss]: 0.000000, [IC-Loss]: 0.006958
# [Batch]: 26, [ST-Loss]: 0.000000, [IC-Loss]: 0.007324
# [Batch]: 27, [ST-Loss]: 0.000000, [IC-Loss]: 0.009766
# [Batch]: 28, [ST-Loss]: 0.000000, [IC-Loss]: 0.009277
# [Batch]: 29, [ST-Loss]: 0.000000, [IC-Loss]: 0.010376
# [Batch]: 30, [ST-Loss]: 0.000000, [IC-Loss]: 0.008423
# [Batch]: 31, [ST-Loss]: 0.000000, [IC-Loss]: 0.010010
# 	[ST-Loss]: 0.000000, [IC-Loss]: 0.008671
# [Correlation] = 0.750000, [DA_ST] = 0.000000, [DA_IC] = 0.009109

# %%
corr_values = [0.0, 0.25, 0.50, 0.75]

TTC_ST_corrs = []
TTC_IC_corrs = []

for corr in corr_values:
    mech = compute_TTC_batch
    s1, i1 = compute_violations(mech, corr)
    
    mech = compute_TTC_batch_switch
    s2, i2 = compute_violations(mech, corr)
    
    TTC_ST_corrs.append(max(s1, s2))
    TTC_IC_corrs.append(max(i1, i2))
    
    print("[Correlation] = %f, [TTC_ST] = %f, [TTC_IC] = %f\n\n"%(corr, TTC_ST_corrs[-1], TTC_IC_corrs[-1]))
# Out:
# [Batch]: 0, [ST-Loss]: 0.018143, [IC-Loss]: 0.016968
# [Batch]: 1, [ST-Loss]: 0.020447, [IC-Loss]: 0.021973
# [Batch]: 2, [ST-Loss]: 0.022888, [IC-Loss]: 0.021118
# [Batch]: 3, [ST-Loss]: 0.023026, [IC-Loss]: 0.020386
# [Batch]: 4, [ST-Loss]: 0.021088, [IC-Loss]: 0.018921
# [Batch]: 5, [ST-Loss]: 0.026077, [IC-Loss]: 0.021606
# [Batch]: 6, [ST-Loss]: 0.026947, [IC-Loss]: 0.024414
# [Batch]: 7, [ST-Loss]: 0.024475, [IC-Loss]: 0.020752
# [Batch]: 8, [ST-Loss]: 0.024445, [IC-Loss]: 0.021240
# [Batch]: 9, [ST-Loss]: 0.021072, [IC-Loss]: 0.017822
# [Batch]: 10, [ST-Loss]: 0.023575, [IC-Loss]: 0.021606
# [Batch]: 11, [ST-Loss]: 0.020432, [IC-Loss]: 0.020020
# [Batch]: 12, [ST-Loss]: 0.020676, [IC-Loss]: 0.019897
# [Batch]: 13, [ST-Loss]: 0.024460, [IC-Loss]: 0.021118
# [Batch]: 14, [ST-Loss]: 0.021194, [IC-Loss]: 0.023071
# [Batch]: 15, [ST-Loss]: 0.025497, [IC-Loss]: 0.024048
# [Batch]: 16, [ST-Loss]: 0.025513, [IC-Loss]: 0.020508
# [Batch]: 17, [ST-Loss]: 0.024963, [IC-Loss]: 0.019653
# [Batch]: 18, [ST-Loss]: 0.021957, [IC-Loss]: 0.017212
# [Batch]: 19, [ST-Loss]: 0.022980, [IC-Loss]: 0.021240
# [Batch]: 20, [ST-Loss]: 0.022125, [IC-Loss]: 0.019409
# [Batch]: 21, [ST-Loss]: 0.024628, [IC-Loss]: 0.021729
# [Batch]: 22, [ST-Loss]: 0.024261, [IC-Loss]: 0.022461
# [Batch]: 23, [ST-Loss]: 0.021744, [IC-Loss]: 0.018677
# [Batch]: 24, [ST-Loss]: 0.020386, [IC-Loss]: 0.018677
# [Batch]: 25, [ST-Loss]: 0.026596, [IC-Loss]: 0.021118
# [Batch]: 26, [ST-Loss]: 0.024445, [IC-Loss]: 0.020630
# [Batch]: 27, [ST-Loss]: 0.023483, [IC-Loss]: 0.020752
# [Batch]: 28, [ST-Loss]: 0.021622, [IC-Loss]: 0.018921
# [Batch]: 29, [ST-Loss]: 0.022705, [IC-Loss]: 0.018433
# [Batch]: 30, [ST-Loss]: 0.024414, [IC-Loss]: 0.019653
# [Batch]: 31, [ST-Loss]: 0.025589, [IC-Loss]: 0.024414
# 	[ST-Loss]: 0.023183, [IC-Loss]: 0.020576
# [Batch]: 0, [ST-Loss]: 0.023590, [IC-Loss]: 0.020874
# [Batch]: 1, [ST-Loss]: 0.021210, [IC-Loss]: 0.016846
# [Batch]: 2, [ST-Loss]: 0.023392, [IC-Loss]: 0.022949
# [Batch]: 3, [ST-Loss]: 0.025864, [IC-Loss]: 0.023071
# [Batch]: 4, [ST-Loss]: 0.022736, [IC-Loss]: 0.020752
# [Batch]: 5, [ST-Loss]: 0.020676, [IC-Loss]: 0.019409
# [Batch]: 6, [ST-Loss]: 0.021469, [IC-Loss]: 0.019653
# [Batch]: 7, [ST-Loss]: 0.024826, [IC-Loss]: 0.022827
# [Batch]: 8, [ST-Loss]: 0.021805, [IC-Loss]: 0.020752
# [Batch]: 9, [ST-Loss]: 0.023544, [IC-Loss]: 0.020508
# [Batch]: 10, [ST-Loss]: 0.019714, [IC-Loss]: 0.019653
# [Batch]: 11, [ST-Loss]: 0.025421, [IC-Loss]: 0.021729
# [Batch]: 12, [ST-Loss]: 0.021332, [IC-Loss]: 0.020142
# [Batch]: 13, [ST-Loss]: 0.022736, [IC-Loss]: 0.021484
# [Batch]: 14, [ST-Loss]: 0.025070, [IC-Loss]: 0.020996
# [Batch]: 15, [ST-Loss]: 0.020584, [IC-Loss]: 0.019043
# [Batch]: 16, [ST-Loss]: 0.022415, [IC-Loss]: 0.019897
# [Batch]: 17, [ST-Loss]: 0.022476, [IC-Loss]: 0.019775
# [Batch]: 18, [ST-Loss]: 0.020706, [IC-Loss]: 0.020142
# [Batch]: 19, [ST-Loss]: 0.021957, [IC-Loss]: 0.021606
# [Batch]: 20, [ST-Loss]: 0.022598, [IC-Loss]: 0.022095
# [Batch]: 21, [ST-Loss]: 0.022537, [IC-Loss]: 0.020508
# [Batch]: 22, [ST-Loss]: 0.022629, [IC-Loss]: 0.019897
# [Batch]: 23, [ST-Loss]: 0.022766, [IC-Loss]: 0.020020
# [Batch]: 24, [ST-Loss]: 0.024139, [IC-Loss]: 0.020996
# [Batch]: 25, [ST-Loss]: 0.022064, [IC-Loss]: 0.020020
# [Batch]: 26, [ST-Loss]: 0.023422, [IC-Loss]: 0.022705
# [Batch]: 27, [ST-Loss]: 0.021713, [IC-Loss]: 0.020630
# [Batch]: 28, [ST-Loss]: 0.022705, [IC-Loss]: 0.018188
# [Batch]: 29, [ST-Loss]: 0.022781, [IC-Loss]: 0.018677
# [Batch]: 30, [ST-Loss]: 0.021149, [IC-Loss]: 0.021606
# [Batch]: 31, [ST-Loss]: 0.022247, [IC-Loss]: 0.022217
# 	[ST-Loss]: 0.022571, [IC-Loss]: 0.020615
# [Correlation] = 0.000000, [TTC_ST] = 0.023183, [TTC_IC] = 0.020615
#
#
# [Batch]: 0, [ST-Loss]: 0.019348, [IC-Loss]: 0.019409
# [Batch]: 1, [ST-Loss]: 0.018692, [IC-Loss]: 0.018433
# [Batch]: 2, [ST-Loss]: 0.020126, [IC-Loss]: 0.015625
# [Batch]: 3, [ST-Loss]: 0.018723, [IC-Loss]: 0.020386
# [Batch]: 4, [ST-Loss]: 0.020752, [IC-Loss]: 0.017578
# [Batch]: 5, [ST-Loss]: 0.020416, [IC-Loss]: 0.020874
# [Batch]: 6, [ST-Loss]: 0.019852, [IC-Loss]: 0.015747
# [Batch]: 7, [ST-Loss]: 0.020889, [IC-Loss]: 0.018921
# [Batch]: 8, [ST-Loss]: 0.020813, [IC-Loss]: 0.018066
# [Batch]: 9, [ST-Loss]: 0.020569, [IC-Loss]: 0.018677
# [Batch]: 10, [ST-Loss]: 0.018799, [IC-Loss]: 0.017578
# [Batch]: 11, [ST-Loss]: 0.019135, [IC-Loss]: 0.017334
# [Batch]: 12, [ST-Loss]: 0.019974, [IC-Loss]: 0.020874
# [Batch]: 13, [ST-Loss]: 0.020432, [IC-Loss]: 0.019897
# [Batch]: 14, [ST-Loss]: 0.016769, [IC-Loss]: 0.017456
# [Batch]: 15, [ST-Loss]: 0.021088, [IC-Loss]: 0.017334
# [Batch]: 16, [ST-Loss]: 0.021210, [IC-Loss]: 0.019287
# [Batch]: 17, [ST-Loss]: 0.021866, [IC-Loss]: 0.018433
# [Batch]: 18, [ST-Loss]: 0.021378, [IC-Loss]: 0.019043
# [Batch]: 19, [ST-Loss]: 0.020279, [IC-Loss]: 0.018555
# [Batch]: 20, [ST-Loss]: 0.020767, [IC-Loss]: 0.017944
# [Batch]: 21, [ST-Loss]: 0.019730, [IC-Loss]: 0.019043
# [Batch]: 22, [ST-Loss]: 0.022339, [IC-Loss]: 0.018677
# [Batch]: 23, [ST-Loss]: 0.019989, [IC-Loss]: 0.019287
# [Batch]: 24, [ST-Loss]: 0.022003, [IC-Loss]: 0.018677
# [Batch]: 25, [ST-Loss]: 0.020752, [IC-Loss]: 0.019043
# [Batch]: 26, [ST-Loss]: 0.022049, [IC-Loss]: 0.021118
# [Batch]: 27, [ST-Loss]: 0.018723, [IC-Loss]: 0.017578
# [Batch]: 28, [ST-Loss]: 0.019592, [IC-Loss]: 0.017700
# [Batch]: 29, [ST-Loss]: 0.019287, [IC-Loss]: 0.017212
# [Batch]: 30, [ST-Loss]: 0.018890, [IC-Loss]: 0.019165
# [Batch]: 31, [ST-Loss]: 0.020447, [IC-Loss]: 0.018066
# 	[ST-Loss]: 0.020177, [IC-Loss]: 0.018532
# [Batch]: 0, [ST-Loss]: 0.019669, [IC-Loss]: 0.018433
# [Batch]: 1, [ST-Loss]: 0.020279, [IC-Loss]: 0.020996
# [Batch]: 2, [ST-Loss]: 0.021561, [IC-Loss]: 0.020020
# [Batch]: 3, [ST-Loss]: 0.021561, [IC-Loss]: 0.019653
# [Batch]: 4, [ST-Loss]: 0.020187, [IC-Loss]: 0.019531
# [Batch]: 5, [ST-Loss]: 0.016708, [IC-Loss]: 0.016602
# [Batch]: 6, [ST-Loss]: 0.018890, [IC-Loss]: 0.018677
# [Batch]: 7, [ST-Loss]: 0.019867, [IC-Loss]: 0.020386
# [Batch]: 8, [ST-Loss]: 0.019104, [IC-Loss]: 0.019775
# [Batch]: 9, [ST-Loss]: 0.022461, [IC-Loss]: 0.020142
# [Batch]: 10, [ST-Loss]: 0.022354, [IC-Loss]: 0.019165
# [Batch]: 11, [ST-Loss]: 0.020004, [IC-Loss]: 0.016846
# [Batch]: 12, [ST-Loss]: 0.022476, [IC-Loss]: 0.019043
# [Batch]: 13, [ST-Loss]: 0.018570, [IC-Loss]: 0.017456
# [Batch]: 14, [ST-Loss]: 0.018326, [IC-Loss]: 0.018311
# [Batch]: 15, [ST-Loss]: 0.020782, [IC-Loss]: 0.019165
# [Batch]: 16, [ST-Loss]: 0.019592, [IC-Loss]: 0.019409
# [Batch]: 17, [ST-Loss]: 0.018433, [IC-Loss]: 0.017456
# [Batch]: 18, [ST-Loss]: 0.020767, [IC-Loss]: 0.018555
# [Batch]: 19, [ST-Loss]: 0.018082, [IC-Loss]: 0.016846
# [Batch]: 20, [ST-Loss]: 0.023468, [IC-Loss]: 0.019287
# [Batch]: 21, [ST-Loss]: 0.020126, [IC-Loss]: 0.018188
# [Batch]: 22, [ST-Loss]: 0.019379, [IC-Loss]: 0.018433
# [Batch]: 23, [ST-Loss]: 0.020828, [IC-Loss]: 0.017944
# [Batch]: 24, [ST-Loss]: 0.021393, [IC-Loss]: 0.019775
# [Batch]: 25, [ST-Loss]: 0.021301, [IC-Loss]: 0.020020
# [Batch]: 26, [ST-Loss]: 0.023026, [IC-Loss]: 0.021729
# [Batch]: 27, [ST-Loss]: 0.019516, [IC-Loss]: 0.018433
# [Batch]: 28, [ST-Loss]: 0.018326, [IC-Loss]: 0.018066
# [Batch]: 29, [ST-Loss]: 0.020660, [IC-Loss]: 0.020630
# [Batch]: 30, [ST-Loss]: 0.021194, [IC-Loss]: 0.019531
# [Batch]: 31, [ST-Loss]: 0.022446, [IC-Loss]: 0.019409
# 	[ST-Loss]: 0.020354, [IC-Loss]: 0.018997
# [Correlation] = 0.250000, [TTC_ST] = 0.020354, [TTC_IC] = 0.018997
#
#
# [Batch]: 0, [ST-Loss]: 0.014755, [IC-Loss]: 0.014648
# [Batch]: 1, [ST-Loss]: 0.012863, [IC-Loss]: 0.011719
# [Batch]: 2, [ST-Loss]: 0.010162, [IC-Loss]: 0.013550
# [Batch]: 3, [ST-Loss]: 0.013794, [IC-Loss]: 0.012451
# [Batch]: 4, [ST-Loss]: 0.015564, [IC-Loss]: 0.014160
# [Batch]: 5, [ST-Loss]: 0.013016, [IC-Loss]: 0.011353
# [Batch]: 6, [ST-Loss]: 0.011292, [IC-Loss]: 0.011108
# [Batch]: 7, [ST-Loss]: 0.014526, [IC-Loss]: 0.014404
# [Batch]: 8, [ST-Loss]: 0.011307, [IC-Loss]: 0.012329
# [Batch]: 9, [ST-Loss]: 0.015167, [IC-Loss]: 0.013916
# [Batch]: 10, [ST-Loss]: 0.013138, [IC-Loss]: 0.012329
# [Batch]: 11, [ST-Loss]: 0.014648, [IC-Loss]: 0.013916
# [Batch]: 12, [ST-Loss]: 0.013107, [IC-Loss]: 0.013184
# [Batch]: 13, [ST-Loss]: 0.014420, [IC-Loss]: 0.013672
# [Batch]: 14, [ST-Loss]: 0.013077, [IC-Loss]: 0.012695
# [Batch]: 15, [ST-Loss]: 0.012497, [IC-Loss]: 0.012329
# [Batch]: 16, [ST-Loss]: 0.010818, [IC-Loss]: 0.012695
# [Batch]: 17, [ST-Loss]: 0.012680, [IC-Loss]: 0.013184
# [Batch]: 18, [ST-Loss]: 0.010071, [IC-Loss]: 0.010010
# [Batch]: 19, [ST-Loss]: 0.014069, [IC-Loss]: 0.014771
# [Batch]: 20, [ST-Loss]: 0.011765, [IC-Loss]: 0.013062
# [Batch]: 21, [ST-Loss]: 0.013672, [IC-Loss]: 0.013062
# [Batch]: 22, [ST-Loss]: 0.010773, [IC-Loss]: 0.011475
# [Batch]: 23, [ST-Loss]: 0.010559, [IC-Loss]: 0.010376
# [Batch]: 24, [ST-Loss]: 0.014175, [IC-Loss]: 0.012573
# [Batch]: 25, [ST-Loss]: 0.014603, [IC-Loss]: 0.014526
# [Batch]: 26, [ST-Loss]: 0.013992, [IC-Loss]: 0.013306
# [Batch]: 27, [ST-Loss]: 0.011292, [IC-Loss]: 0.012329
# [Batch]: 28, [ST-Loss]: 0.012741, [IC-Loss]: 0.011230
# [Batch]: 29, [ST-Loss]: 0.012527, [IC-Loss]: 0.014771
# [Batch]: 30, [ST-Loss]: 0.012436, [IC-Loss]: 0.011475
# [Batch]: 31, [ST-Loss]: 0.011703, [IC-Loss]: 0.013062
# 	[ST-Loss]: 0.012850, [IC-Loss]: 0.012802
# [Batch]: 0, [ST-Loss]: 0.011887, [IC-Loss]: 0.013306
# [Batch]: 1, [ST-Loss]: 0.013565, [IC-Loss]: 0.012207
# [Batch]: 2, [ST-Loss]: 0.015076, [IC-Loss]: 0.014404
# [Batch]: 3, [ST-Loss]: 0.011780, [IC-Loss]: 0.012817
# [Batch]: 4, [ST-Loss]: 0.012848, [IC-Loss]: 0.013428
# [Batch]: 5, [ST-Loss]: 0.013016, [IC-Loss]: 0.013428
# [Batch]: 6, [ST-Loss]: 0.013062, [IC-Loss]: 0.014160
# [Batch]: 7, [ST-Loss]: 0.011749, [IC-Loss]: 0.013306
# [Batch]: 8, [ST-Loss]: 0.013657, [IC-Loss]: 0.014404
# [Batch]: 9, [ST-Loss]: 0.012695, [IC-Loss]: 0.012207
# [Batch]: 10, [ST-Loss]: 0.011902, [IC-Loss]: 0.013672
# [Batch]: 11, [ST-Loss]: 0.012527, [IC-Loss]: 0.012939
# [Batch]: 12, [ST-Loss]: 0.012451, [IC-Loss]: 0.012451
# [Batch]: 13, [ST-Loss]: 0.011765, [IC-Loss]: 0.012451
# [Batch]: 14, [ST-Loss]: 0.014557, [IC-Loss]: 0.015015
# [Batch]: 15, [ST-Loss]: 0.012619, [IC-Loss]: 0.013184
# [Batch]: 16, [ST-Loss]: 0.013199, [IC-Loss]: 0.011841
# [Batch]: 17, [ST-Loss]: 0.014587, [IC-Loss]: 0.013672
# [Batch]: 18, [ST-Loss]: 0.015244, [IC-Loss]: 0.017700
# [Batch]: 19, [ST-Loss]: 0.013138, [IC-Loss]: 0.014404
# [Batch]: 20, [ST-Loss]: 0.013428, [IC-Loss]: 0.013550
# [Batch]: 21, [ST-Loss]: 0.011719, [IC-Loss]: 0.013672
# [Batch]: 22, [ST-Loss]: 0.013290, [IC-Loss]: 0.013428
# [Batch]: 23, [ST-Loss]: 0.013885, [IC-Loss]: 0.013916
# [Batch]: 24, [ST-Loss]: 0.013565, [IC-Loss]: 0.012695
# [Batch]: 25, [ST-Loss]: 0.012955, [IC-Loss]: 0.015259
# [Batch]: 26, [ST-Loss]: 0.012817, [IC-Loss]: 0.014038
# [Batch]: 27, [ST-Loss]: 0.013474, [IC-Loss]: 0.011475
# [Batch]: 28, [ST-Loss]: 0.013580, [IC-Loss]: 0.013672
# [Batch]: 29, [ST-Loss]: 0.012543, [IC-Loss]: 0.013062
# [Batch]: 30, [ST-Loss]: 0.015121, [IC-Loss]: 0.014160
# [Batch]: 31, [ST-Loss]: 0.012390, [IC-Loss]: 0.012451
# 	[ST-Loss]: 0.013128, [IC-Loss]: 0.013512
# [Correlation] = 0.500000, [TTC_ST] = 0.013128, [TTC_IC] = 0.013512
#
#
# [Batch]: 0, [ST-Loss]: 0.004669, [IC-Loss]: 0.005859
# [Batch]: 1, [ST-Loss]: 0.004913, [IC-Loss]: 0.004761
# [Batch]: 2, [ST-Loss]: 0.003891, [IC-Loss]: 0.005127
# [Batch]: 3, [ST-Loss]: 0.004715, [IC-Loss]: 0.005249
# [Batch]: 4, [ST-Loss]: 0.003540, [IC-Loss]: 0.005615
# [Batch]: 5, [ST-Loss]: 0.005127, [IC-Loss]: 0.005981
# [Batch]: 6, [ST-Loss]: 0.004135, [IC-Loss]: 0.006104
# [Batch]: 7, [ST-Loss]: 0.004807, [IC-Loss]: 0.004272
# [Batch]: 8, [ST-Loss]: 0.003860, [IC-Loss]: 0.003662
# [Batch]: 9, [ST-Loss]: 0.003571, [IC-Loss]: 0.002808
# [Batch]: 10, [ST-Loss]: 0.005234, [IC-Loss]: 0.005371
# [Batch]: 11, [ST-Loss]: 0.005463, [IC-Loss]: 0.005249
# [Batch]: 12, [ST-Loss]: 0.004349, [IC-Loss]: 0.004517
# [Batch]: 13, [ST-Loss]: 0.004395, [IC-Loss]: 0.004639
# [Batch]: 14, [ST-Loss]: 0.004517, [IC-Loss]: 0.004883
# [Batch]: 15, [ST-Loss]: 0.003677, [IC-Loss]: 0.003906
# [Batch]: 16, [ST-Loss]: 0.003998, [IC-Loss]: 0.003296
# [Batch]: 17, [ST-Loss]: 0.004135, [IC-Loss]: 0.003784
# [Batch]: 18, [ST-Loss]: 0.003387, [IC-Loss]: 0.003662
# [Batch]: 19, [ST-Loss]: 0.004486, [IC-Loss]: 0.005371
# [Batch]: 20, [ST-Loss]: 0.004135, [IC-Loss]: 0.004517
# [Batch]: 21, [ST-Loss]: 0.005219, [IC-Loss]: 0.005371
# [Batch]: 22, [ST-Loss]: 0.004440, [IC-Loss]: 0.004150
# [Batch]: 23, [ST-Loss]: 0.006165, [IC-Loss]: 0.005005
# [Batch]: 24, [ST-Loss]: 0.005783, [IC-Loss]: 0.005859
# [Batch]: 25, [ST-Loss]: 0.004196, [IC-Loss]: 0.004517
# [Batch]: 26, [ST-Loss]: 0.005600, [IC-Loss]: 0.005493
# [Batch]: 27, [ST-Loss]: 0.005096, [IC-Loss]: 0.005615
# [Batch]: 28, [ST-Loss]: 0.004211, [IC-Loss]: 0.005005
# [Batch]: 29, [ST-Loss]: 0.004105, [IC-Loss]: 0.005005
# [Batch]: 30, [ST-Loss]: 0.006195, [IC-Loss]: 0.005615
# [Batch]: 31, [ST-Loss]: 0.005386, [IC-Loss]: 0.006104
# 	[ST-Loss]: 0.004606, [IC-Loss]: 0.004887
# [Batch]: 0, [ST-Loss]: 0.003845, [IC-Loss]: 0.004639
# [Batch]: 1, [ST-Loss]: 0.004364, [IC-Loss]: 0.005737
# [Batch]: 2, [ST-Loss]: 0.004761, [IC-Loss]: 0.004272
# [Batch]: 3, [ST-Loss]: 0.003784, [IC-Loss]: 0.004395
# [Batch]: 4, [ST-Loss]: 0.005707, [IC-Loss]: 0.003906
# [Batch]: 5, [ST-Loss]: 0.004288, [IC-Loss]: 0.005127
# [Batch]: 6, [ST-Loss]: 0.004547, [IC-Loss]: 0.004761
# [Batch]: 7, [ST-Loss]: 0.005142, [IC-Loss]: 0.005371
# [Batch]: 8, [ST-Loss]: 0.003922, [IC-Loss]: 0.004395
# [Batch]: 9, [ST-Loss]: 0.004288, [IC-Loss]: 0.003662
# [Batch]: 10, [ST-Loss]: 0.004181, [IC-Loss]: 0.005371
# [Batch]: 11, [ST-Loss]: 0.004883, [IC-Loss]: 0.005371
# [Batch]: 12, [ST-Loss]: 0.003296, [IC-Loss]: 0.005005
# [Batch]: 13, [ST-Loss]: 0.003769, [IC-Loss]: 0.005615
# [Batch]: 14, [ST-Loss]: 0.003677, [IC-Loss]: 0.005493
# [Batch]: 15, [ST-Loss]: 0.004059, [IC-Loss]: 0.004761
# [Batch]: 16, [ST-Loss]: 0.005066, [IC-Loss]: 0.004150
# [Batch]: 17, [ST-Loss]: 0.004501, [IC-Loss]: 0.004761
# [Batch]: 18, [ST-Loss]: 0.003204, [IC-Loss]: 0.004517
# [Batch]: 19, [ST-Loss]: 0.003342, [IC-Loss]: 0.003540
# [Batch]: 20, [ST-Loss]: 0.004654, [IC-Loss]: 0.005249
# [Batch]: 21, [ST-Loss]: 0.006241, [IC-Loss]: 0.005615
# [Batch]: 22, [ST-Loss]: 0.004196, [IC-Loss]: 0.003906
# [Batch]: 23, [ST-Loss]: 0.004410, [IC-Loss]: 0.005249
# [Batch]: 24, [ST-Loss]: 0.004105, [IC-Loss]: 0.004761
# [Batch]: 25, [ST-Loss]: 0.005356, [IC-Loss]: 0.005737
# [Batch]: 26, [ST-Loss]: 0.004929, [IC-Loss]: 0.005493
# [Batch]: 27, [ST-Loss]: 0.003784, [IC-Loss]: 0.004883
# [Batch]: 28, [ST-Loss]: 0.005219, [IC-Loss]: 0.004395
# [Batch]: 29, [ST-Loss]: 0.004349, [IC-Loss]: 0.005859
# [Batch]: 30, [ST-Loss]: 0.005798, [IC-Loss]: 0.005371
# [Batch]: 31, [ST-Loss]: 0.004822, [IC-Loss]: 0.004639
# 	[ST-Loss]: 0.004453, [IC-Loss]: 0.004875
# [Correlation] = 0.750000, [TTC_ST] = 0.004606, [TTC_IC] = 0.004887

# %%
corr_values = [0.0, 0.25, 0.50, 0.75]

RSD_One_ST_corrs = []
RSD_One_IC_corrs = []

for corr in corr_values:
    mech = compute_one_RSD_batch
    s1, i1 = compute_violations(mech, corr)
    
    mech = compute_one_RSD_batch_switch
    s2, i2 = compute_violations(mech, corr)
    
    RSD_One_ST_corrs.append(max(s1, s2))
    RSD_One_IC_corrs.append(max(i1, i2))
    
    print("[Correlation] = %f, [RSD_One_ST] = %f, [RSD_One_IC] = %f\n\n"%(corr, RSD_One_ST_corrs[-1], RSD_One_IC_corrs[-1]))
# Out:
# [Batch]: 0, [ST-Loss]: 0.082469, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.079827, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.083868, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.078901, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.080659, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.083473, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.080798, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.081990, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.082311, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.084429, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.079664, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.079264, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.083806, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.079353, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.078991, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.081168, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.082755, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.083722, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.080141, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.083653, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.082345, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.080112, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.083494, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.080687, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.081148, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.083543, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.082744, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.084923, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.082784, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.082820, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.080649, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.082196, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.081834, [IC-Loss]: 0.000000
# [Batch]: 0, [ST-Loss]: 0.082721, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.079079, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.081537, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.085605, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.080667, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.080023, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.082126, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.082377, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.080799, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.084811, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.080785, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.082367, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.081091, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.082481, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.080711, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.086007, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.079963, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.081374, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.081192, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.076752, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.080641, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.079970, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.080507, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.080350, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.083881, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.079848, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.083117, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.084480, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.082546, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.080126, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.081089, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.080847, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.081558, [IC-Loss]: 0.000000
# [Correlation] = 0.000000, [RSD_One_ST] = 0.081834, [RSD_One_IC] = 0.000000
#
#
# [Batch]: 0, [ST-Loss]: 0.085750, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.089055, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.086757, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.084965, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.086270, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.085628, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.084391, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.083465, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.088442, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.086477, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.085639, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.085008, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.083387, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.086313, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.082356, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.086754, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.086171, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.089828, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.085576, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.088590, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.080501, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.083688, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.085345, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.086602, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.085745, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.085544, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.083457, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.084683, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.081865, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.086902, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.084060, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.083387, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.085394, [IC-Loss]: 0.000000
# [Batch]: 0, [ST-Loss]: 0.083262, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.087772, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.084750, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.088988, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.085264, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.084458, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.081880, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.089088, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.084820, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.090439, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.085419, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.080159, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.086267, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.088747, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.084988, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.083065, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.086436, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.083127, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.083517, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.084484, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.082569, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.086447, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.083537, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.086624, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.078368, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.084081, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.087310, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.086520, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.082792, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.089169, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.086707, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.084691, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.085179, [IC-Loss]: 0.000000
# [Correlation] = 0.250000, [RSD_One_ST] = 0.085394, [RSD_One_IC] = 0.000000
#
#
# [Batch]: 0, [ST-Loss]: 0.094493, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.092677, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.097290, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.107380, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.094669, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.100381, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.095317, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.096800, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.094679, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.095134, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.095247, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.093557, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.095199, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.095272, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.098927, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.094158, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.099409, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.100896, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.101285, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.099221, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.095371, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.094107, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.099601, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.091862, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.099956, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.094029, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.090102, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.094656, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.099026, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.105071, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.098729, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.095951, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.096889, [IC-Loss]: 0.000000
# [Batch]: 0, [ST-Loss]: 0.096349, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.097717, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.098393, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.093515, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.093298, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.098707, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.101108, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.098855, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.098242, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.099987, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.099710, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.102018, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.095946, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.091776, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.101736, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.099213, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.098129, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.097666, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.101171, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.094370, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.095018, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.098404, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.096720, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.101147, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.098735, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.096948, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.093920, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.093779, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.094804, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.095718, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.101348, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.092755, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.097413, [IC-Loss]: 0.000000
# [Correlation] = 0.500000, [RSD_One_ST] = 0.097413, [RSD_One_IC] = 0.000000
#
#
# [Batch]: 0, [ST-Loss]: 0.123051, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.117223, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.117425, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.122390, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.119163, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.114165, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.116181, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.122344, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.123361, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.119986, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.119080, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.119457, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.116979, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.114355, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.119007, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.119602, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.121995, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.120777, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.117896, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.117208, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.119730, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.121398, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.115761, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.121408, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.114767, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.118410, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.120090, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.115654, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.119154, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.118639, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.119018, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.120505, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.118943, [IC-Loss]: 0.000000
# [Batch]: 0, [ST-Loss]: 0.115223, [IC-Loss]: 0.000000
# [Batch]: 1, [ST-Loss]: 0.120390, [IC-Loss]: 0.000000
# [Batch]: 2, [ST-Loss]: 0.121445, [IC-Loss]: 0.000000
# [Batch]: 3, [ST-Loss]: 0.117501, [IC-Loss]: 0.000000
# [Batch]: 4, [ST-Loss]: 0.121860, [IC-Loss]: 0.000000
# [Batch]: 5, [ST-Loss]: 0.116565, [IC-Loss]: 0.000000
# [Batch]: 6, [ST-Loss]: 0.122977, [IC-Loss]: 0.000000
# [Batch]: 7, [ST-Loss]: 0.113823, [IC-Loss]: 0.000000
# [Batch]: 8, [ST-Loss]: 0.114836, [IC-Loss]: 0.000000
# [Batch]: 9, [ST-Loss]: 0.112637, [IC-Loss]: 0.000000
# [Batch]: 10, [ST-Loss]: 0.118643, [IC-Loss]: 0.000000
# [Batch]: 11, [ST-Loss]: 0.116891, [IC-Loss]: 0.000000
# [Batch]: 12, [ST-Loss]: 0.112211, [IC-Loss]: 0.000000
# [Batch]: 13, [ST-Loss]: 0.114878, [IC-Loss]: 0.000000
# [Batch]: 14, [ST-Loss]: 0.122306, [IC-Loss]: 0.000000
# [Batch]: 15, [ST-Loss]: 0.112480, [IC-Loss]: 0.000000
# [Batch]: 16, [ST-Loss]: 0.120480, [IC-Loss]: 0.000000
# [Batch]: 17, [ST-Loss]: 0.120720, [IC-Loss]: 0.000000
# [Batch]: 18, [ST-Loss]: 0.117141, [IC-Loss]: 0.000000
# [Batch]: 19, [ST-Loss]: 0.115141, [IC-Loss]: 0.000000
# [Batch]: 20, [ST-Loss]: 0.109592, [IC-Loss]: 0.000000
# [Batch]: 21, [ST-Loss]: 0.116161, [IC-Loss]: 0.000000
# [Batch]: 22, [ST-Loss]: 0.122412, [IC-Loss]: 0.000000
# [Batch]: 23, [ST-Loss]: 0.115534, [IC-Loss]: 0.000000
# [Batch]: 24, [ST-Loss]: 0.119356, [IC-Loss]: 0.000000
# [Batch]: 25, [ST-Loss]: 0.121921, [IC-Loss]: 0.000000
# [Batch]: 26, [ST-Loss]: 0.118020, [IC-Loss]: 0.000000
# [Batch]: 27, [ST-Loss]: 0.110357, [IC-Loss]: 0.000000
# [Batch]: 28, [ST-Loss]: 0.115166, [IC-Loss]: 0.000000
# [Batch]: 29, [ST-Loss]: 0.118532, [IC-Loss]: 0.000000
# [Batch]: 30, [ST-Loss]: 0.115703, [IC-Loss]: 0.000000
# [Batch]: 31, [ST-Loss]: 0.121798, [IC-Loss]: 0.000000
# 	[ST-Loss]: 0.117272, [IC-Loss]: 0.000000
# [Correlation] = 0.750000, [RSD_One_ST] = 0.118943, [RSD_One_IC] = 0.000000

# %%
# corr_values = [0.0, 0.25, 0.50, 0.75]

# SD_ST_corrs = []
# SD_IC_corrs = []

# for corr in corr_values:
#     mech = compute_SD_batch
#     s1, i1 = compute_violations(mech, corr)
    
#     mech = compute_SD_batch_switch
#     s2, i2 = compute_violations(mech, corr)
    
#     SD_ST_corrs.append(max(s1, s2))
#     SD_IC_corrs.append(max(i1, i2))
    
#     print("[Correlation] = %f, [SD_ST] = %f, [SD_IC] = %f\n\n"%(corr, SD_ST_corrs[-1], SD_IC_corrs[-1]))

# %%
print("Results -")
for i, corr in enumerate(corr_values):
    print("%dth index in the following data represents corresponding value for correlation %f\n\n"%(i, corr))
    
print("DA ST scores =", DA_ST_corrs)
print("DA IC scores =", DA_IC_corrs, "\n\n")

print("TTC ST scores =", TTC_ST_corrs)
print("TTC IC scores =", TTC_IC_corrs, "\n\n")

print("RSD One ST scores =", RSD_One_ST_corrs)
print("RSD One IC scores =", RSD_One_IC_corrs, "\n\n")

# print("SD ST scores =", SD_ST_corrs)
# print("SD IC scores =", SD_IC_corrs, "\n\n")

ST_scores = {"DA_ST" : DA_ST_corrs, "TTC_ST" : TTC_ST_corrs, "RSD_One_ST" : RSD_One_ST_corrs}
IC_scores = {"DA_IC" : DA_IC_corrs, "TTC_IC" : TTC_IC_corrs, "RSD_One_IC" : RSD_One_IC_corrs}
# Out:
# Results -
# 0th index in the following data represents corresponding value for correlation 0.000000
#
#
# 1th index in the following data represents corresponding value for correlation 0.250000
#
#
# 2th index in the following data represents corresponding value for correlation 0.500000
#
#
# 3th index in the following data represents corresponding value for correlation 0.750000
#
#
# DA ST scores = [0.0, 0.0, 0.0, 0.0]
# DA IC scores = [0.05620574951171875, 0.04791259765625, 0.0283966064453125, 0.0091094970703125]
#
#
# TTC ST scores = [0.02318286895751953, 0.020354270935058594, 0.013127803802490234, 0.0046062469482421875]
# TTC IC scores = [0.0206146240234375, 0.0189971923828125, 0.01351165771484375, 0.004886627197265625]
#
#
# RSD One ST scores = [0.08183395365873973, 0.08539383278952706, 0.09741250177224477, 0.11894305050373077]
# RSD One IC scores = [2.2114547945152087e-17, 2.3372630099841138e-17, 2.4766316935429683e-17, 1.9797859894852372e-17]

# %% [markdown]
# # Computing ST, IC for Convex Combination

# %%
def STABILITY_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams):
    ST_VIOL = np.zeros(len(lams))
    R_1 = mech_1(P, Q)
    R_2 = mech_2(P, Q)
    for idx, lam in enumerate(lams):        
        R = lam * R_1 + (1 - lam) * R_2
        ST_VIOL[idx] = STABILITY_VIOLATION_BATCH(P, Q, R)
        
    return ST_VIOL


def IR_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams):
    IR_VIOL = np.zeros(len(lams))
    R_1 = mech_1(P, Q)
    R_2 = mech_2(P, Q)
    for idx, lam in enumerate(lams):        
        R = lam * R_1 + (1 - lam) * R_2
        IR_VIOL[idx] = IR_VIOLATION_BATCH(P, Q, R)
        
    return IR_VIOL


def IC_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams, data_generator):
    R_1 = mech_1(P, Q)
    R_2 = mech_2(P, Q)
    
    IC_viol_P = np.zeros(len(lams))
    IC_viol_Q = np.zeros(len(lams))
    
    for agent_idx in range(num_agents):
        P_mis, Q_mis = data_generator.generate_all_misreports(P, Q, agent_idx = agent_idx, is_P = True, include_truncation = True)
        
        R_mis_1 = mech_1(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis_1 = R_mis_1.reshape(batch_size, -1, num_agents, num_agents)
        
        R_mis_2 = mech_2(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis_2 = R_mis_2.reshape(batch_size, -1, num_agents, num_agents)
        
        for idx, lam in enumerate(lams):
            R = lam * R_1 + (1 - lam) * R_2
            R_mis = lam * R_mis_1 + (1 - lam) * R_mis_2
            
            R_diff = (R_mis[:, :, agent_idx, :] - R[:, None, agent_idx, :])*(P[:, None, agent_idx, :] > 0)
            IDX = np.argsort(-P[:, agent_idx, :])
            IDX = np.tile(IDX[:, None, :], (1, R_mis.shape[1], 1))
        
            FOSD_viol = np.cumsum(np.take_along_axis(R_diff, IDX, axis=-1), -1)
            IC_viol_P[idx]  += np.maximum(FOSD_viol, 0).max(-1).max(-1).mean(-1)
            
        P_mis, Q_mis = data_generator.generate_all_misreports(P, Q, agent_idx = agent_idx, is_P = False, include_truncation = True)
        
        R_mis_1 = mech_1(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis_1 = R_mis_1.reshape(batch_size, -1, num_agents, num_agents)
        
        R_mis_2 = mech_2(P_mis.reshape(-1, num_agents, num_agents),
                                 Q_mis.reshape(-1, num_agents, num_agents))
        R_mis_2 = R_mis_2.reshape(batch_size, -1, num_agents, num_agents)

        for idx, lam in enumerate(lams):
            R = lam * R_1 + (1 - lam) * R_2
            R_mis = lam * R_mis_1 + (1 - lam) * R_mis_2
            
            R_diff = (R_mis[:, :, :, agent_idx] - R[:, None, :, agent_idx])*(Q[:, None, :, agent_idx] > 0)
            IDX = np.argsort(-Q[:, :, agent_idx])
            IDX = np.tile(IDX[:, None, :], (1, R_mis.shape[1], 1))
        
            FOSD_viol = np.cumsum(np.take_along_axis(R_diff, IDX, axis=-1), -1)
            IC_viol_Q[idx] += np.maximum(FOSD_viol, 0).max(-1).max(-1).mean(-1)
        
    IC_viol = (IC_viol_P + IC_viol_Q)/(2 * num_agents)
    
    return IC_viol

# %%
def compute_combination_violations(mech_1, mech_2, lams, corr):
    VAL_ST_LOSS = np.zeros(len(lams))
    VAL_IC_LOSS = np.zeros(len(lams))
    
    data_generator = Data(num_agents = num_agents, prob = prob, corr = corr)

    for j in range(num_validation_batches):
        P, Q = data_generator.generate_batch(batch_size)

        ST_LOSS = STABILITY_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams) + IR_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams)
        IC_LOSS = IC_VIOLATION_BATCH_COMBO(P, Q, mech_1, mech_2, lams, data_generator)

        VAL_ST_LOSS += ST_LOSS
        VAL_IC_LOSS += IC_LOSS
        
        print("[Batch]:", j, "[ST-Loss]:", ST_LOSS, "[IC-Loss]:", IC_LOSS)

    ST_arr = VAL_ST_LOSS/num_validation_batches
    IC_arr = VAL_IC_LOSS/num_validation_batches
    
    return ST_arr.tolist(), IC_arr.tolist()

# %%
lams = [0.0, 0.25, 0.5, 0.75, 1.0]
corr_values = [0.0, 0.25, 0.50, 0.75]

# Choose whichever side performed better and comment another
mech_1, tag_1 = compute_one_RSD_batch, "RSD_One"
# mech_1, tag_1 = compute_one_RSD_batch_switch, "RSD_One_Switch"

mech_2, tag_2 = compute_TTC_batch, "TTC"
# mech_2, tag_2 = compute_TTC_batch_switch, "TTC_Switch"

mech_3, tag_3 = compute_DA_batch, "DA"
# mech_3, tag_3 = compute_DA_batch_switch, "DA_Switch"

ST_1_corrs = []
IC_1_corrs = []
for corr in corr_values:
    ST_1, IC_1 = compute_combination_violations(mech_1, mech_2, lams, corr)
    ST_1_corrs.append(ST_1)
    IC_1_corrs.append(IC_1)
    print(f"[Correlation] = {corr}\n\t[ST] = {ST_1_corrs[-1]},\n\t[IC] = {IC_1_corrs[-1]}\n\n")

ST_2_corrs = []
IC_2_corrs = []
for corr in corr_values:
    ST_2, IC_2 = compute_combination_violations(mech_2, mech_3, lams, corr)
    ST_2_corrs.append(ST_2)
    IC_2_corrs.append(IC_2)
    print(f"[Correlation] = {corr}\n\t[ST] = {ST_2_corrs[-1]},\n\t[IC] = {IC_2_corrs[-1]}\n\n")
    
ST_3_corrs = []
IC_3_corrs = []
for corr in corr_values:
    ST_3, IC_3 = compute_combination_violations(mech_1, mech_3, lams, corr)
    ST_3_corrs.append(ST_3)
    IC_3_corrs.append(IC_3)
    print(f"[Correlation] = {corr}\n\t[ST] = {ST_3_corrs[-1]},\n\t[IC] = {IC_3_corrs[-1]}\n\n")
    
combination_ST = {tag_1+"_"+tag_2+"_ST" : ST_1_corrs, tag_2+"_"+tag_3+"_ST" : ST_2_corrs, tag_1+"_"+tag_3+"_ST" : ST_3_corrs}
combination_IC = {tag_1+"_"+tag_2+"_IC" : IC_1_corrs, tag_2+"_"+tag_3+"_IC" : IC_2_corrs, tag_1+"_"+tag_3+"_IC" : IC_3_corrs}
# Out:
# [Batch]: 0 [ST-Loss]: [0.02426147 0.0375694  0.05182949 0.06704174 0.08320615] [IC-Loss]: [2.28271484e-02 1.71203613e-02 1.14135742e-02 5.70678711e-03
#  2.14680500e-17]
# [Batch]: 1 [ST-Loss]: [0.02522278 0.03884906 0.0533461  0.0687139  0.08495246] [IC-Loss]: [2.16064453e-02 1.62048340e-02 1.08032227e-02 5.40161133e-03
#  2.20296329e-17]
# [Batch]: 2 [ST-Loss]: [0.02391052 0.03695549 0.05097762 0.0659769  0.08195334] [IC-Loss]: [2.17285156e-02 1.62963867e-02 1.08642578e-02 5.43212891e-03
#  2.26793072e-17]
# [Batch]: 3 [ST-Loss]: [0.02035522 0.03336205 0.04746046 0.06265046 0.07893205] [IC-Loss]: [1.94091797e-02 1.45568848e-02 9.70458984e-03 4.85229492e-03
#  2.23455762e-17]
# [Batch]: 4 [ST-Loss]: [0.02410889 0.036314   0.04942955 0.06345552 0.07839192] [IC-Loss]: [2.41699219e-02 1.81274414e-02 1.20849609e-02 6.04248047e-03
#  2.18263450e-17]
# [Batch]: 5 [ST-Loss]: [0.02444458 0.03730536 0.05105146 0.06568289 0.08119965] [IC-Loss]: [2.12402344e-02 1.59301758e-02 1.06201172e-02 5.31005859e-03
#  2.13274426e-17]
# [Batch]: 6 [ST-Loss]: [0.02159119 0.03609228 0.05132643 0.06729364 0.08399391] [IC-Loss]: [2.02636719e-02 1.51977539e-02 1.01318359e-02 5.06591797e-03
#  2.22219094e-17]
# [Batch]: 7 [ST-Loss]: [0.02622986 0.03799504 0.05087829 0.0648796  0.07999897] [IC-Loss]: [2.38037109e-02 1.78527832e-02 1.19018555e-02 5.95092773e-03
#  2.16713380e-17]
# [Batch]: 8 [ST-Loss]: [0.02378845 0.03698282 0.0512004  0.06644121 0.08270523] [IC-Loss]: [2.25830078e-02 1.69372559e-02 1.12915039e-02 5.64575195e-03
#  2.26352614e-17]
# [Batch]: 9 [ST-Loss]: [0.02388    0.03640407 0.04984864 0.06421369 0.07949924] [IC-Loss]: [2.03857422e-02 1.52893066e-02 1.01928711e-02 5.09643555e-03
#  2.18610733e-17]
# [Batch]: 10 [ST-Loss]: [0.02391052 0.03666089 0.05023124 0.06462155 0.07983184] [IC-Loss]: [2.12402344e-02 1.59301758e-02 1.06201172e-02 5.31005859e-03
#  2.20770667e-17]
# [Batch]: 11 [ST-Loss]: [0.0244751  0.03704609 0.05053798 0.06495075 0.08028441] [IC-Loss]: [2.23388672e-02 1.67541504e-02 1.11694336e-02 5.58471680e-03
#  2.18737788e-17]
# [Batch]: 12 [ST-Loss]: [0.02278137 0.0357596  0.04989654 0.06519218 0.08164652] [IC-Loss]: [2.05078125e-02 1.53808594e-02 1.02539063e-02 5.12695312e-03
#  2.20203155e-17]
# [Batch]: 13 [ST-Loss]: [0.02313232 0.03685105 0.05148111 0.06702249 0.08347519] [IC-Loss]: [2.02636719e-02 1.51977539e-02 1.01318359e-02 5.06591797e-03
#  2.25141357e-17]
# [Batch]: 14 [ST-Loss]: [0.02409363 0.0375717  0.05197792 0.06731229 0.0835748 ] [IC-Loss]: [2.14843750e-02 1.61132813e-02 1.07421875e-02 5.37109375e-03
#  2.15908698e-17]
# [Batch]: 15 [ST-Loss]: [0.02229309 0.03616474 0.05099763 0.06679179 0.08354719] [IC-Loss]: [1.95312500e-02 1.46484375e-02 9.76562500e-03 4.88281250e-03
#  2.30553898e-17]
# [Batch]: 16 [ST-Loss]: [0.0223999  0.03534756 0.04929709 0.06424849 0.08020176] [IC-Loss]: [2.03857422e-02 1.52893066e-02 1.01928711e-02 5.09643555e-03
#  2.26666017e-17]
# [Batch]: 17 [ST-Loss]: [0.02371216 0.03693978 0.05117574 0.06642005 0.0826727 ] [IC-Loss]: [2.23388672e-02 1.67541504e-02 1.11694336e-02 5.58471680e-03
#  2.23362588e-17]
# [Batch]: 18 [ST-Loss]: [0.02206421 0.03474701 0.04845224 0.06317991 0.07893001] [IC-Loss]: [1.96533203e-02 1.47399902e-02 9.82666016e-03 4.91333008e-03
#  2.18348153e-17]
# [Batch]: 19 [ST-Loss]: [0.02206421 0.03453933 0.04789902 0.0621433  0.07727215] [IC-Loss]: [2.03857422e-02 1.52893066e-02 1.01928711e-02 5.09643555e-03
#  2.17306303e-17]
# [Batch]: 20 [ST-Loss]: [0.02229309 0.03546813 0.04946433 0.0642817  0.07992024] [IC-Loss]: [2.25830078e-02 1.69372559e-02 1.12915039e-02 5.64575195e-03
#  2.23819986e-17]
# [Batch]: 21 [ST-Loss]: [0.02149963 0.03490865 0.04913506 0.06417884 0.08004   ] [IC-Loss]: [1.96533203e-02 1.47399902e-02 9.82666016e-03 4.91333008e-03
#  2.24912658e-17]
# [Batch]: 22 [ST-Loss]: [0.02496338 0.03757974 0.05113492 0.06562892 0.08106173] [IC-Loss]: [1.89208984e-02 1.41906738e-02 9.46044922e-03 4.73022461e-03
#  2.27343643e-17]
# [Batch]: 23 [ST-Loss]: [0.0247345  0.03803024 0.05214759 0.06708656 0.08284714] [IC-Loss]: [2.27050781e-02 1.70288086e-02 1.13525391e-02 5.67626953e-03
#  2.19965986e-17]
# [Batch]: 24 [ST-Loss]: [0.02378845 0.03703792 0.05117191 0.06619042 0.08209345] [IC-Loss]: [2.22167969e-02 1.66625977e-02 1.11083984e-02 5.55419922e-03
#  2.14883788e-17]
# [Batch]: 25 [ST-Loss]: [0.02305603 0.03625594 0.05039669 0.0654783  0.08150074] [IC-Loss]: [2.16064453e-02 1.62048340e-02 1.08032227e-02 5.40161133e-03
#  2.20067630e-17]
# [Batch]: 26 [ST-Loss]: [0.02220154 0.03654755 0.05160925 0.06738663 0.08387968] [IC-Loss]: [2.20947266e-02 1.65710449e-02 1.10473633e-02 5.52368164e-03
#  2.15146369e-17]
# [Batch]: 27 [ST-Loss]: [0.02323914 0.03674278 0.05112812 0.06639515 0.08254388] [IC-Loss]: [2.07519531e-02 1.55639648e-02 1.03759766e-02 5.18798828e-03
#  2.23210122e-17]
# [Batch]: 28 [ST-Loss]: [0.02474976 0.03741628 0.05108286 0.06574948 0.08141616] [IC-Loss]: [2.29492188e-02 1.72119141e-02 1.14746094e-02 5.73730469e-03
#  2.21202654e-17]
# [Batch]: 29 [ST-Loss]: [0.02430725 0.03588291 0.04864295 0.06258737 0.07771617] [IC-Loss]: [2.07519531e-02 1.55639648e-02 1.03759766e-02 5.18798828e-03
#  2.11402483e-17]
# [Batch]: 30 [ST-Loss]: [0.02578735 0.0380842  0.05128737 0.06539686 0.08041268] [IC-Loss]: [2.07519531e-02 1.55639648e-02 1.03759766e-02 5.18798828e-03
#  2.13088079e-17]
# [Batch]: 31 [ST-Loss]: [0.02450562 0.03810227 0.05259213 0.06797519 0.08425146] [IC-Loss]: [2.38037109e-02 1.78527832e-02 1.19018555e-02 5.95092773e-03
#  2.25505582e-17]
# [Correlation] = 0.0
# 	[ST] = [0.023557662963867188, 0.03660981067352825, 0.050596503747834115, 0.06551774218678474, 0.08137352599038017],
# 	[IC] = [0.021404266357421875, 0.016053199768066417, 0.010702133178710957, 0.005351066589355469, 2.205689676517959e-17]
#
#
# [Batch]: 0 [ST-Loss]: [0.02035522 0.03472633 0.05014494 0.06661105 0.08412467] [IC-Loss]: [1.69677734e-02 1.27258301e-02 8.48388672e-03 4.24194336e-03
#  2.35839384e-17]
# [Batch]: 1 [ST-Loss]: [0.01953125 0.03504214 0.05150325 0.06891456 0.08727609] [IC-Loss]: [1.68457031e-02 1.26342773e-02 8.42285156e-03 4.21142578e-03
#  2.31663511e-17]
# [Batch]: 2 [ST-Loss]: [0.02003479 0.03486765 0.05082785 0.06791538 0.08613025] [IC-Loss]: [1.96533203e-02 1.47399902e-02 9.82666016e-03 4.91333008e-03
#  2.31587278e-17]
# [Batch]: 3 [ST-Loss]: [0.02005005 0.03525355 0.05146449 0.06868288 0.08690871] [IC-Loss]: [1.78222656e-02 1.33666992e-02 8.91113281e-03 4.45556641e-03
#  2.33798034e-17]
# [Batch]: 4 [ST-Loss]: [0.02055359 0.0355146  0.05146155 0.06839445 0.0863133 ] [IC-Loss]: [1.85546875e-02 1.39160156e-02 9.27734375e-03 4.63867188e-03
#  2.34136847e-17]
# [Batch]: 5 [ST-Loss]: [0.01818848 0.03184726 0.04660645 0.06246606 0.07942608] [IC-Loss]: [1.64794922e-02 1.23596191e-02 8.23974609e-03 4.11987305e-03
#  2.32129379e-17]
# [Batch]: 6 [ST-Loss]: [0.01971436 0.03563595 0.05252999 0.07039647 0.08923539] [IC-Loss]: [1.72119141e-02 1.29089355e-02 8.60595703e-03 4.30297852e-03
#  2.34992351e-17]
# [Batch]: 7 [ST-Loss]: [0.01940918 0.03515546 0.05167773 0.06897599 0.08705023] [IC-Loss]: [1.78222656e-02 1.33666992e-02 8.91113281e-03 4.45556641e-03
#  2.30138852e-17]
# [Batch]: 8 [ST-Loss]: [0.02177429 0.03614707 0.05149917 0.06783061 0.08514137] [IC-Loss]: [1.98974609e-02 1.49230957e-02 9.94873047e-03 4.97436523e-03
#  2.30418373e-17]
# [Batch]: 9 [ST-Loss]: [0.01983643 0.03609572 0.05325582 0.0713167  0.09027839] [IC-Loss]: [1.97753906e-02 1.48315430e-02 9.88769531e-03 4.94384766e-03
#  2.39363041e-17]
# [Batch]: 10 [ST-Loss]: [0.02194214 0.03614319 0.05134189 0.06753823 0.08473221] [IC-Loss]: [1.85546875e-02 1.39160156e-02 9.27734375e-03 4.63867188e-03
#  2.31968443e-17]
# [Batch]: 11 [ST-Loss]: [0.01896667 0.03379923 0.04987264 0.06718691 0.08574202] [IC-Loss]: [1.90429688e-02 1.42822266e-02 9.52148438e-03 4.76074219e-03
#  2.31892210e-17]
# [Batch]: 12 [ST-Loss]: [0.01945496 0.03368115 0.0490303  0.06550241 0.08309746] [IC-Loss]: [2.01416016e-02 1.51062012e-02 1.00708008e-02 5.03540039e-03
#  2.31722803e-17]
# [Batch]: 13 [ST-Loss]: [0.01844788 0.03385674 0.05018308 0.06742692 0.08558824] [IC-Loss]: [1.83105469e-02 1.37329102e-02 9.15527344e-03 4.57763672e-03
#  2.33366047e-17]
# [Batch]: 14 [ST-Loss]: [0.01841736 0.03405501 0.05057182 0.06796779 0.08624291] [IC-Loss]: [1.78222656e-02 1.33666992e-02 8.91113281e-03 4.45556641e-03
#  2.29884742e-17]
# [Batch]: 15 [ST-Loss]: [0.02204895 0.03524086 0.04952863 0.06491227 0.08139178] [IC-Loss]: [1.98974609e-02 1.49230957e-02 9.94873047e-03 4.97436523e-03
#  2.27817981e-17]
# [Batch]: 16 [ST-Loss]: [0.01843262 0.03392209 0.05034595 0.0677042  0.08599684] [IC-Loss]: [1.89208984e-02 1.41906738e-02 9.46044922e-03 4.73022461e-03
#  2.38710825e-17]
# [Batch]: 17 [ST-Loss]: [0.01908875 0.03472693 0.05141637 0.06915706 0.08794901] [IC-Loss]: [1.70898438e-02 1.28173828e-02 8.54492188e-03 4.27246094e-03
#  2.31511045e-17]
# [Batch]: 18 [ST-Loss]: [0.0193634  0.03421067 0.05006499 0.06692638 0.08479481] [IC-Loss]: [1.73339844e-02 1.30004883e-02 8.66699219e-03 4.33349609e-03
#  2.41810966e-17]
# [Batch]: 19 [ST-Loss]: [0.01629639 0.03232323 0.04938708 0.06748794 0.08662581] [IC-Loss]: [1.74560547e-02 1.30920410e-02 8.72802734e-03 4.36401367e-03
#  2.31062118e-17]
# [Batch]: 20 [ST-Loss]: [0.01960754 0.03463758 0.05064569 0.06763189 0.08559616] [IC-Loss]: [1.73339844e-02 1.30004883e-02 8.66699219e-03 4.33349609e-03
#  2.32663010e-17]
# [Batch]: 21 [ST-Loss]: [0.01965332 0.03454119 0.05054465 0.0676637  0.08589835] [IC-Loss]: [1.85546875e-02 1.39160156e-02 9.27734375e-03 4.63867188e-03
#  2.33120408e-17]
# [Batch]: 22 [ST-Loss]: [0.01976013 0.03507713 0.05129763 0.06842165 0.08644917] [IC-Loss]: [1.63574219e-02 1.22680664e-02 8.17871094e-03 4.08935547e-03
#  2.32434311e-17]
# [Batch]: 23 [ST-Loss]: [0.0234375  0.03655913 0.05084332 0.0662901  0.08289944] [IC-Loss]: [2.34375000e-02 1.75781250e-02 1.17187500e-02 5.85937500e-03
#  2.35780091e-17]
# [Batch]: 24 [ST-Loss]: [0.02029419 0.03438431 0.04958779 0.06590465 0.08333487] [IC-Loss]: [1.98974609e-02 1.49230957e-02 9.94873047e-03 4.97436523e-03
#  2.35830913e-17]
# [Batch]: 25 [ST-Loss]: [0.01986694 0.03488178 0.0508303  0.06771253 0.08552845] [IC-Loss]: [1.79443359e-02 1.34582520e-02 8.97216797e-03 4.48608398e-03
#  2.27623164e-17]
# [Batch]: 26 [ST-Loss]: [0.02079773 0.03581874 0.0517591  0.0686188  0.08639786] [IC-Loss]: [1.89208984e-02 1.41906738e-02 9.46044922e-03 4.73022461e-03
#  2.36652535e-17]
# [Batch]: 27 [ST-Loss]: [0.02268982 0.03738359 0.05304955 0.06968769 0.08729802] [IC-Loss]: [2.07519531e-02 1.55639648e-02 1.03759766e-02 5.18798828e-03
#  2.30037208e-17]
# [Batch]: 28 [ST-Loss]: [0.02070618 0.0359695  0.05232686 0.06977825 0.08832367] [IC-Loss]: [1.96533203e-02 1.47399902e-02 9.82666016e-03 4.91333008e-03
#  2.35280342e-17]
# [Batch]: 29 [ST-Loss]: [0.0209198  0.0350926  0.05049582 0.06712946 0.08499352] [IC-Loss]: [1.98974609e-02 1.49230957e-02 9.94873047e-03 4.97436523e-03
#  2.31587278e-17]
# [Batch]: 30 [ST-Loss]: [0.01683044 0.03251967 0.04905833 0.06644642 0.08468395] [IC-Loss]: [1.72119141e-02 1.29089355e-02 8.60595703e-03 4.30297852e-03
#  2.24700900e-17]
# [Batch]: 31 [ST-Loss]: [0.02127075 0.0351464  0.05011085 0.06616409 0.08330613] [IC-Loss]: [1.95312500e-02 1.46484375e-02 9.76562500e-03 4.88281250e-03
#  2.27470698e-17]
# [Correlation] = 0.25
# 	[ST] = [0.01992940902709961, 0.034820513696306295, 0.05072699694169893, 0.06764885876327753, 0.08558609916104211],
# 	[IC] = [0.018596649169921875, 0.013947486877441418, 0.00929832458496096, 0.004649162292480469, 2.3271859648897478e-17]
#
#
# [Batch]: 0 [ST-Loss]: [0.01261902 0.03152234 0.05189859 0.07374775 0.09706985] [IC-Loss]: [1.30615234e-02 9.79614258e-03 6.53076172e-03 3.26538086e-03
#  2.47020218e-17]
# [Batch]: 1 [ST-Loss]: [0.01577759 0.03469793 0.05479305 0.07606295 0.09850762] [IC-Loss]: [1.36718750e-02 1.02539063e-02 6.83593750e-03 3.41796875e-03
#  2.45207568e-17]
# [Batch]: 2 [ST-Loss]: [0.01313782 0.03195433 0.05204598 0.07341278 0.09605471] [IC-Loss]: [1.24511719e-02 9.33837891e-03 6.22558594e-03 3.11279297e-03
#  2.48036658e-17]
# [Batch]: 3 [ST-Loss]: [0.01094055 0.03148357 0.05307706 0.07572103 0.09941546] [IC-Loss]: [1.26953125e-02 9.52148438e-03 6.34765625e-03 3.17382812e-03
#  2.47579260e-17]
# [Batch]: 4 [ST-Loss]: [0.01194763 0.03312947 0.05534463 0.07859313 0.10287497] [IC-Loss]: [1.29394531e-02 9.70458984e-03 6.46972656e-03 3.23486328e-03
#  2.47350561e-17]
# [Batch]: 5 [ST-Loss]: [0.01193237 0.03039681 0.0503573  0.07181384 0.09476643] [IC-Loss]: [1.23291016e-02 9.24682617e-03 6.16455078e-03 3.08227539e-03
#  2.40845348e-17]
# [Batch]: 6 [ST-Loss]: [0.01150513 0.030652   0.05116414 0.07304154 0.0962842 ] [IC-Loss]: [1.30615234e-02 9.79614258e-03 6.53076172e-03 3.26538086e-03
#  2.42607177e-17]
# [Batch]: 7 [ST-Loss]: [0.01269531 0.031844   0.05225127 0.07391712 0.09684155] [IC-Loss]: [1.45263672e-02 1.08947754e-02 7.26318359e-03 3.63159180e-03
#  2.49612139e-17]
# [Batch]: 8 [ST-Loss]: [0.01086426 0.03206265 0.05426962 0.07748517 0.10170931] [IC-Loss]: [1.12304688e-02 8.42285156e-03 5.61523438e-03 2.80761719e-03
#  2.43708320e-17]
# [Batch]: 9 [ST-Loss]: [0.01397705 0.03410651 0.05530649 0.07757701 0.10091805] [IC-Loss]: [1.40380859e-02 1.05285645e-02 7.01904297e-03 3.50952148e-03
#  2.45156746e-17]
# [Batch]: 10 [ST-Loss]: [0.01351929 0.03198387 0.0515824  0.07231489 0.09418133] [IC-Loss]: [1.48925781e-02 1.11694336e-02 7.44628906e-03 3.72314453e-03
#  2.46732227e-17]
# [Batch]: 11 [ST-Loss]: [0.01132202 0.0324776  0.05473448 0.07809265 0.10255212] [IC-Loss]: [1.12304688e-02 8.42285156e-03 5.61523438e-03 2.80761719e-03
#  2.49120860e-17]
# [Batch]: 12 [ST-Loss]: [0.01353455 0.03210208 0.05186833 0.07283328 0.09499696] [IC-Loss]: [1.40380859e-02 1.05285645e-02 7.01904297e-03 3.50952148e-03
#  2.46884693e-17]
# [Batch]: 13 [ST-Loss]: [0.01446533 0.03504964 0.05664237 0.07924353 0.10285311] [IC-Loss]: [1.29394531e-02 9.70458984e-03 6.46972656e-03 3.23486328e-03
#  2.54541871e-17]
# [Batch]: 14 [ST-Loss]: [0.01248169 0.03204792 0.05289177 0.07501325 0.09841235] [IC-Loss]: [1.42822266e-02 1.07116699e-02 7.14111328e-03 3.57055664e-03
#  2.41760144e-17]
# [Batch]: 15 [ST-Loss]: [0.01130676 0.03116214 0.05222685 0.07450089 0.09798426] [IC-Loss]: [1.15966797e-02 8.69750977e-03 5.79833984e-03 2.89916992e-03
#  2.49095449e-17]
# [Batch]: 16 [ST-Loss]: [0.01225281 0.03122336 0.05160993 0.07341252 0.09663113] [IC-Loss]: [1.17187500e-02 8.78906250e-03 5.85937500e-03 2.92968750e-03
#  2.50349058e-17]
# [Batch]: 17 [ST-Loss]: [0.01516724 0.03512034 0.05619497 0.07839115 0.10170886] [IC-Loss]: [1.26953125e-02 9.52148438e-03 6.34765625e-03 3.17382812e-03
#  2.44623115e-17]
# [Batch]: 18 [ST-Loss]: [0.01403809 0.0326257  0.05262796 0.07404488 0.09687646] [IC-Loss]: [1.36718750e-02 1.02539063e-02 6.83593750e-03 3.41796875e-03
#  2.47731726e-17]
# [Batch]: 19 [ST-Loss]: [0.01203918 0.03101143 0.05147684 0.0734354  0.09688711] [IC-Loss]: [1.33056641e-02 9.97924805e-03 6.65283203e-03 3.32641602e-03
#  2.43699849e-17]
# [Batch]: 20 [ST-Loss]: [0.01390076 0.03216501 0.05171728 0.07255757 0.09468587] [IC-Loss]: [1.33056641e-02 9.97924805e-03 6.65283203e-03 3.32641602e-03
#  2.53584724e-17]
# [Batch]: 21 [ST-Loss]: [0.01441956 0.03330518 0.05342044 0.07476532 0.09733984] [IC-Loss]: [1.51367188e-02 1.13525391e-02 7.56835938e-03 3.78417969e-03
#  2.47858781e-17]
# [Batch]: 22 [ST-Loss]: [0.01264954 0.03163448 0.05191356 0.07348676 0.09635409] [IC-Loss]: [1.09863281e-02 8.23974609e-03 5.49316406e-03 2.74658203e-03
#  2.41658500e-17]
# [Batch]: 23 [ST-Loss]: [0.01371765 0.03288741 0.05325456 0.07481912 0.09758107] [IC-Loss]: [1.41601562e-02 1.06201172e-02 7.08007813e-03 3.54003906e-03
#  2.49459673e-17]
# [Batch]: 24 [ST-Loss]: [0.01101685 0.03010222 0.05059104 0.07248329 0.09577897] [IC-Loss]: [1.17187500e-02 8.78906250e-03 5.85937500e-03 2.92968750e-03
#  2.48163713e-17]
# [Batch]: 25 [ST-Loss]: [0.01298523 0.0311924  0.05099591 0.07239576 0.09539194] [IC-Loss]: [1.35498047e-02 1.01623535e-02 6.77490234e-03 3.38745117e-03
#  2.47147273e-17]
# [Batch]: 26 [ST-Loss]: [0.01402283 0.03251558 0.05235755 0.07354876 0.0960892 ] [IC-Loss]: [1.47705078e-02 1.10778809e-02 7.38525391e-03 3.69262695e-03
#  2.43962429e-17]
# [Batch]: 27 [ST-Loss]: [0.01356506 0.03365634 0.05505426 0.07775883 0.10177006] [IC-Loss]: [1.39160156e-02 1.04370117e-02 6.95800781e-03 3.47900391e-03
#  2.49019216e-17]
# [Batch]: 28 [ST-Loss]: [0.01327515 0.03165098 0.05149317 0.07280171 0.0955766 ] [IC-Loss]: [1.31835938e-02 9.88769531e-03 6.59179688e-03 3.29589844e-03
#  2.51416319e-17]
# [Batch]: 29 [ST-Loss]: [0.0135498  0.03385644 0.05520014 0.0775809  0.10099872] [IC-Loss]: [1.35498047e-02 1.01623535e-02 6.77490234e-03 3.38745117e-03
#  2.48206065e-17]
# [Batch]: 30 [ST-Loss]: [0.01477051 0.03294252 0.05258747 0.07370535 0.09629615] [IC-Loss]: [1.41601562e-02 1.06201172e-02 7.08007813e-03 3.54003906e-03
#  2.43733731e-17]
# [Batch]: 31 [ST-Loss]: [0.01119995 0.0309108  0.05185093 0.07402034 0.09741902] [IC-Loss]: [1.18408203e-02 8.88061523e-03 5.92041016e-03 2.96020508e-03
#  2.43860786e-17]
# [Correlation] = 0.5
# 	[ST] = [0.01295614242553711, 0.03229603290350901, 0.05290001113381651, 0.07476807711645961, 0.09790023085143833],
# 	[IC] = [0.01314544677734375, 0.009859085083007818, 0.006572723388671902, 0.0032863616943359375, 2.4686669368608177e-17]
# [Batch]: 0 [ST-Loss]: [0.00469971 0.02970646 0.05666248 0.08556777 0.11642234] [IC-Loss]: [5.49316406e-03 4.11987305e-03 2.74658203e-03 1.37329102e-03
#  1.95681551e-17]
# [Batch]: 1 [ST-Loss]: [0.00559998 0.03035424 0.05728904 0.08640438 0.11770026] [IC-Loss]: [5.61523438e-03 4.21142578e-03 2.80761719e-03 1.40380859e-03
#  1.90802642e-17]
# [Batch]: 2 [ST-Loss]: [0.00456238 0.03147169 0.06032864 0.09113324 0.12388547] [IC-Loss]: [4.27246094e-03 3.20434570e-03 2.13623047e-03 1.06811523e-03
#  1.94851459e-17]
# [Batch]: 3 [ST-Loss]: [0.00375366 0.02798215 0.05451869 0.08336328 0.11451591] [IC-Loss]: [6.22558594e-03 4.66918945e-03 3.11279297e-03 1.55639648e-03
#  1.91556501e-17]
# [Batch]: 4 [ST-Loss]: [0.00617981 0.03152702 0.05877741 0.08793098 0.11898772] [IC-Loss]: [5.85937500e-03 4.39453125e-03 2.92968750e-03 1.46484375e-03
#  1.98671578e-17]
# [Batch]: 5 [ST-Loss]: [0.00413513 0.02985383 0.05772596 0.08775151 0.11993048] [IC-Loss]: [4.02832031e-03 3.02124023e-03 2.01416016e-03 1.00708008e-03
#  1.95063217e-17]
# [Batch]: 6 [ST-Loss]: [0.00520325 0.02943359 0.0558994  0.08460067 0.11553741] [IC-Loss]: [4.63867188e-03 3.47900391e-03 2.31933594e-03 1.15966797e-03
#  1.94893811e-17]
# [Batch]: 7 [ST-Loss]: [0.00442505 0.02888148 0.05542536 0.08405669 0.11477547] [IC-Loss]: [4.51660156e-03 3.38745117e-03 2.25830078e-03 1.12915039e-03
#  2.01839481e-17]
# [Batch]: 8 [ST-Loss]: [0.00419617 0.02921705 0.05632865 0.08553097 0.11682399] [IC-Loss]: [5.12695312e-03 3.84521484e-03 2.56347656e-03 1.28173828e-03
#  1.96714932e-17]
# [Batch]: 9 [ST-Loss]: [0.00556946 0.03058651 0.05762845 0.08669525 0.11778694] [IC-Loss]: [5.85937500e-03 4.39453125e-03 2.92968750e-03 1.46484375e-03
#  1.96664110e-17]
# [Batch]: 10 [ST-Loss]: [0.0058136  0.03065884 0.05761162 0.08667195 0.11783981] [IC-Loss]: [3.78417969e-03 2.83813477e-03 1.89208984e-03 9.46044922e-04
#  1.97002923e-17]
# [Batch]: 11 [ST-Loss]: [0.00506592 0.0289471  0.05510767 0.08354765 0.11426703] [IC-Loss]: [6.83593750e-03 5.12695313e-03 3.41796875e-03 1.70898438e-03
#  1.95207213e-17]
# [Batch]: 12 [ST-Loss]: [0.004776   0.03034993 0.05809737 0.08801831 0.12011276] [IC-Loss]: [5.61523438e-03 4.21142578e-03 2.80761719e-03 1.40380859e-03
#  1.98044773e-17]
# [Batch]: 13 [ST-Loss]: [0.00537109 0.02972297 0.0562962  0.08509077 0.1161067 ] [IC-Loss]: [5.37109375e-03 4.02832031e-03 2.68554688e-03 1.34277344e-03
#  2.03702953e-17]
# [Batch]: 14 [ST-Loss]: [0.00416565 0.02927053 0.05642715 0.08563553 0.11689565] [IC-Loss]: [5.85937500e-03 4.39453125e-03 2.92968750e-03 1.46484375e-03
#  2.03076149e-17]
# [Batch]: 15 [ST-Loss]: [0.00367737 0.03041443 0.05890403 0.08914617 0.12114085] [IC-Loss]: [3.78417969e-03 2.83813477e-03 1.89208984e-03 9.46044922e-04
#  1.95274976e-17]
# [Batch]: 16 [ST-Loss]: [0.00535583 0.02972522 0.05619903 0.08477725 0.11545989] [IC-Loss]: [6.83593750e-03 5.12695313e-03 3.41796875e-03 1.70898438e-03
#  1.99552492e-17]
# [Batch]: 17 [ST-Loss]: [0.00480652 0.03030635 0.05807943 0.08812578 0.12044538] [IC-Loss]: [3.54003906e-03 2.65502930e-03 1.77001953e-03 8.85009766e-04
#  1.86711473e-17]
# [Batch]: 18 [ST-Loss]: [0.00497437 0.02962169 0.0566289  0.085996   0.11772299] [IC-Loss]: [4.27246094e-03 3.20434570e-03 2.13623047e-03 1.06811523e-03
#  1.89405037e-17]
# [Batch]: 19 [ST-Loss]: [0.00444031 0.02930154 0.05634138 0.08555984 0.11695692] [IC-Loss]: [5.73730469e-03 4.30297852e-03 2.86865234e-03 1.43432617e-03
#  1.92005428e-17]
# [Batch]: 20 [ST-Loss]: [0.0032196  0.02767439 0.05425436 0.0829595  0.11378982] [IC-Loss]: [5.37109375e-03 4.02832031e-03 2.68554688e-03 1.34277344e-03
#  2.04253525e-17]
# [Batch]: 21 [ST-Loss]: [0.00454712 0.0299847  0.05755101 0.08724606 0.11906984] [IC-Loss]: [3.54003906e-03 2.65502930e-03 1.77001953e-03 8.85009766e-04
#  1.94792167e-17]
# [Batch]: 22 [ST-Loss]: [0.00627136 0.03100699 0.05796885 0.08715695 0.11857128] [IC-Loss]: [6.59179688e-03 4.94384766e-03 3.29589844e-03 1.64794922e-03
#  1.95368149e-17]
# [Batch]: 23 [ST-Loss]: [0.00427246 0.02865174 0.05507257 0.08353496 0.11403889] [IC-Loss]: [5.61523438e-03 4.21142578e-03 2.80761719e-03 1.40380859e-03
#  2.06023824e-17]
# [Batch]: 24 [ST-Loss]: [0.00265503 0.0281392  0.05576551 0.08553395 0.11744452] [IC-Loss]: [4.02832031e-03 3.02124023e-03 2.01416016e-03 1.00708008e-03
#  2.05693481e-17]
# [Batch]: 25 [ST-Loss]: [0.00558472 0.0314258  0.05901274 0.08834554 0.11942421] [IC-Loss]: [6.59179688e-03 4.94384766e-03 3.29589844e-03 1.64794922e-03
#  2.01221147e-17]
# [Batch]: 26 [ST-Loss]: [0.00549316 0.03043211 0.05750293 0.08670563 0.11804019] [IC-Loss]: [4.76074219e-03 3.57055664e-03 2.38037109e-03 1.19018555e-03
#  1.96333767e-17]
# [Batch]: 27 [ST-Loss]: [0.00456238 0.02922779 0.05591542 0.08462526 0.11535732] [IC-Loss]: [6.22558594e-03 4.66918945e-03 3.11279297e-03 1.55639648e-03
#  2.03211674e-17]
# [Batch]: 28 [ST-Loss]: [0.00326538 0.02960288 0.05801375 0.08849798 0.12105558] [IC-Loss]: [3.54003906e-03 2.65502930e-03 1.77001953e-03 8.85009766e-04
#  1.99010391e-17]
# [Batch]: 29 [ST-Loss]: [0.00552368 0.02974064 0.05616089 0.08478442 0.11561124] [IC-Loss]: [6.10351562e-03 4.57763672e-03 3.05175781e-03 1.52587891e-03
#  2.01034800e-17]
# [Batch]: 30 [ST-Loss]: [0.00428772 0.02831041 0.0546498  0.0833059  0.11427869] [IC-Loss]: [4.88281250e-03 3.66210938e-03 2.44140625e-03 1.22070312e-03
#  2.00518110e-17]
# [Batch]: 31 [ST-Loss]: [0.00570679 0.02980363 0.05624914 0.0850433  0.11618612] [IC-Loss]: [5.49316406e-03 4.11987305e-03 2.74658203e-03 1.37329102e-03
#  1.91895314e-17]
# [Correlation] = 0.75
# 	[ST] = [0.0047550201416015625, 0.02972915385746293, 0.05682480790548854, 0.08604198228567839, 0.11738067699803245],
# 	[IC] = [0.00518798828125, 0.003890991210937506, 0.0025939941406250186, 0.0012969970703125, 1.9737747025376918e-17]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.00527477 0.01118088 0.01771832 0.02488708] [IC-Loss]: [0.05432129 0.04498291 0.03564453 0.02880859 0.02197266]
# [Batch]: 1 [ST-Loss]: [0.         0.00472355 0.01005173 0.01598454 0.02252197] [IC-Loss]: [0.05578613 0.04574585 0.03570557 0.02792358 0.0201416 ]
# [Batch]: 2 [ST-Loss]: [0.         0.00541878 0.01145172 0.01809883 0.02536011] [IC-Loss]: [0.05578613 0.04672241 0.03765869 0.03109741 0.02453613]
# [Batch]: 3 [ST-Loss]: [0.         0.00492668 0.01044464 0.01655388 0.02325439] [IC-Loss]: [0.05102539 0.0423584  0.03369141 0.0269165  0.0201416 ]
# [Batch]: 4 [ST-Loss]: [0.         0.0051012  0.01078415 0.01704884 0.02389526] [IC-Loss]: [0.05725098 0.04647827 0.03570557 0.02688599 0.01806641]
# [Batch]: 5 [ST-Loss]: [0.         0.00533295 0.0112381  0.01771545 0.02476501] [IC-Loss]: [0.05529785 0.04544067 0.0355835  0.02780151 0.02001953]
# [Batch]: 6 [ST-Loss]: [0.         0.00499725 0.01056671 0.01670837 0.02342224] [IC-Loss]: [0.05822754 0.04766846 0.03710938 0.02947998 0.02185059]
# [Batch]: 7 [ST-Loss]: [0.         0.00417709 0.00899506 0.01445389 0.02055359] [IC-Loss]: [0.05090332 0.04251099 0.03411865 0.02737427 0.02062988]
# [Batch]: 8 [ST-Loss]: [0.         0.00436783 0.00941467 0.01514053 0.02154541] [IC-Loss]: [0.05810547 0.04724121 0.03637695 0.02764893 0.0189209 ]
# [Batch]: 9 [ST-Loss]: [0.         0.00461388 0.00997162 0.01607323 0.0229187 ] [IC-Loss]: [0.05358887 0.04446411 0.03533936 0.02810669 0.02087402]
# [Batch]: 10 [ST-Loss]: [0.         0.00434399 0.00921249 0.01460552 0.02052307] [IC-Loss]: [0.06335449 0.05111694 0.03887939 0.02890015 0.0189209 ]
# [Batch]: 11 [ST-Loss]: [0.         0.0046072  0.0099144  0.01592159 0.02262878] [IC-Loss]: [0.05932617 0.04840088 0.03747559 0.02960205 0.02172852]
# [Batch]: 12 [ST-Loss]: [0.         0.00453186 0.00978088 0.01574707 0.02243042] [IC-Loss]: [0.05554199 0.0461731  0.0368042  0.02987671 0.02294922]
# [Batch]: 13 [ST-Loss]: [0.         0.00484943 0.0103035  0.01636219 0.02302551] [IC-Loss]: [0.05603027 0.04611206 0.03619385 0.02822876 0.02026367]
# [Batch]: 14 [ST-Loss]: [0.         0.00512791 0.0110054  0.01763248 0.02500916] [IC-Loss]: [0.06237793 0.05075073 0.03912354 0.0296936  0.02026367]
# [Batch]: 15 [ST-Loss]: [0.         0.00496101 0.01057434 0.01683998 0.02375793] [IC-Loss]: [0.05651855 0.04663086 0.03674316 0.0289917  0.02124023]
# [Batch]: 16 [ST-Loss]: [0.         0.00466919 0.00989532 0.01567841 0.02201843] [IC-Loss]: [0.05737305 0.04669189 0.03601074 0.02783203 0.01965332]
# [Batch]: 17 [ST-Loss]: [0.         0.00488281 0.01027679 0.01618195 0.02259827] [IC-Loss]: [0.05517578 0.04534912 0.03552246 0.02746582 0.01940918]
# [Batch]: 18 [ST-Loss]: [0.         0.00417805 0.00897598 0.01439381 0.02043152] [IC-Loss]: [0.05908203 0.04824829 0.03741455 0.02896118 0.02050781]
# [Batch]: 19 [ST-Loss]: [0.         0.00476933 0.01036453 0.01678562 0.02403259] [IC-Loss]: [0.05029297 0.04229736 0.03430176 0.02886963 0.0234375 ]
# [Batch]: 20 [ST-Loss]: [0.         0.0041399  0.00896072 0.01446247 0.02064514] [IC-Loss]: [0.05200195 0.04278564 0.03356934 0.02667236 0.01977539]
# [Batch]: 21 [ST-Loss]: [0.         0.00414085 0.00897217 0.01449394 0.02070618] [IC-Loss]: [0.06359863 0.05160522 0.03961182 0.0296936  0.01977539]
# [Batch]: 22 [ST-Loss]: [0.         0.004282   0.00915527 0.01461983 0.02067566] [IC-Loss]: [0.05236816 0.0430603  0.03375244 0.02651978 0.01928711]
# [Batch]: 23 [ST-Loss]: [0.         0.00524521 0.01114655 0.01770401 0.0249176 ] [IC-Loss]: [0.05944824 0.04928589 0.03912354 0.03128052 0.0234375 ]
# [Batch]: 24 [ST-Loss]: [0.         0.00500584 0.01058578 0.01673985 0.02346802] [IC-Loss]: [0.04919434 0.0411377  0.03308105 0.0267334  0.02038574]
# [Batch]: 25 [ST-Loss]: [0.         0.00514889 0.01077652 0.0168829  0.02346802] [IC-Loss]: [0.05285645 0.04385376 0.03485107 0.02767944 0.02050781]
# [Batch]: 26 [ST-Loss]: [0.         0.00484657 0.01037598 0.01658821 0.02348328] [IC-Loss]: [0.05822754 0.04769897 0.03717041 0.02914429 0.02111816]
# [Batch]: 27 [ST-Loss]: [0.         0.00486279 0.01021957 0.01607037 0.02241516] [IC-Loss]: [0.05456543 0.0447998  0.03503418 0.02758789 0.0201416 ]
# [Batch]: 28 [ST-Loss]: [0.         0.00518227 0.01094818 0.01729774 0.02423096] [IC-Loss]: [0.05517578 0.04528809 0.03540039 0.02807617 0.02075195]
# [Batch]: 29 [ST-Loss]: [0.         0.00506687 0.01063156 0.01669407 0.02325439] [IC-Loss]: [0.05822754 0.04690552 0.0355835  0.0262146  0.0168457 ]
# [Batch]: 30 [ST-Loss]: [0.         0.00416946 0.00907898 0.01472855 0.02111816] [IC-Loss]: [0.05273438 0.04327393 0.03381348 0.02655029 0.01928711]
# [Batch]: 31 [ST-Loss]: [0.         0.00484085 0.01036835 0.01658249 0.02348328] [IC-Loss]: [0.05395508 0.04440308 0.03485107 0.02713013 0.01940918]
# [Correlation] = 0.0
# 	[ST] = [0.0, 0.004774570465087891, 0.010175704956054688, 0.01620340347290039, 0.022857666015625],
# 	[IC] = [0.055866241455078125, 0.04592132568359375, 0.035976409912109375, 0.028242111206054688, 0.0205078125]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.00450897 0.00966644 0.01547241 0.02192688] [IC-Loss]: [0.05102539 0.04196167 0.03289795 0.02603149 0.01916504]
# [Batch]: 1 [ST-Loss]: [0.         0.00490856 0.01054764 0.01691723 0.02401733] [IC-Loss]: [0.04724121 0.03997803 0.03271484 0.02807617 0.0234375 ]
# [Batch]: 2 [ST-Loss]: [0.         0.00376225 0.00812912 0.01310062 0.01867676] [IC-Loss]: [0.04882812 0.04003906 0.03125    0.02441406 0.01757812]
# [Batch]: 3 [ST-Loss]: [0.         0.0038166  0.00829315 0.01342964 0.01922607] [IC-Loss]: [0.04736328 0.0390625  0.03076172 0.02484131 0.0189209 ]
# [Batch]: 4 [ST-Loss]: [0.         0.00440025 0.00949097 0.01527214 0.02174377] [IC-Loss]: [0.05004883 0.04110718 0.03216553 0.02554321 0.0189209 ]
# [Batch]: 5 [ST-Loss]: [0.         0.00443268 0.00955963 0.01538086 0.02189636] [IC-Loss]: [0.04406738 0.03720093 0.03033447 0.02578735 0.02124023]
# [Batch]: 6 [ST-Loss]: [0.         0.00403976 0.00875092 0.01413345 0.02018738] [IC-Loss]: [0.0489502  0.04052734 0.03210449 0.02526855 0.01843262]
# [Batch]: 7 [ST-Loss]: [0.         0.0042181  0.00904465 0.01447964 0.02052307] [IC-Loss]: [0.04956055 0.04077148 0.03198242 0.02532959 0.01867676]
# [Batch]: 8 [ST-Loss]: [0.         0.00458622 0.00984573 0.01577854 0.02238464] [IC-Loss]: [0.04772949 0.0397644  0.03179932 0.02560425 0.01940918]
# [Batch]: 9 [ST-Loss]: [0.         0.00415421 0.00888062 0.01417923 0.02005005] [IC-Loss]: [0.04345703 0.0362854  0.02911377 0.02371216 0.01831055]
# [Batch]: 10 [ST-Loss]: [0.         0.00387955 0.00830078 0.0132637  0.01876831] [IC-Loss]: [0.046875   0.03894043 0.03100586 0.02508545 0.01916504]
# [Batch]: 11 [ST-Loss]: [0.         0.00366783 0.00798798 0.01296043 0.01858521] [IC-Loss]: [0.04992676 0.04104614 0.03216553 0.02529907 0.01843262]
# [Batch]: 12 [ST-Loss]: [0.         0.00404835 0.00879288 0.01423359 0.02037048] [IC-Loss]: [0.04931641 0.04083252 0.03234863 0.02648926 0.02062988]
# [Batch]: 13 [ST-Loss]: [0.         0.00354576 0.00764465 0.01229668 0.01750183] [IC-Loss]: [0.04516602 0.03707886 0.0289917  0.02279663 0.01660156]
# [Batch]: 14 [ST-Loss]: [0.         0.00452232 0.00980377 0.01584435 0.02264404] [IC-Loss]: [0.04699707 0.03903198 0.03106689 0.02505493 0.01904297]
# [Batch]: 15 [ST-Loss]: [0.         0.00454426 0.00974655 0.01560688 0.02212524] [IC-Loss]: [0.05310059 0.04345703 0.03381348 0.0269165  0.02001953]
# [Batch]: 16 [ST-Loss]: [0.         0.0046463  0.00993347 0.01586151 0.02243042] [IC-Loss]: [0.05273438 0.04342651 0.03411865 0.02713013 0.0201416 ]
# [Batch]: 17 [ST-Loss]: [0.         0.00393295 0.00852203 0.01376724 0.01966858] [IC-Loss]: [0.04870605 0.04025269 0.03179932 0.02572632 0.01965332]
# [Batch]: 18 [ST-Loss]: [0.         0.00439072 0.009552   0.01548386 0.02218628] [IC-Loss]: [0.04907227 0.04104614 0.03302002 0.02688599 0.02075195]
# [Batch]: 19 [ST-Loss]: [0.         0.00470638 0.00989914 0.01557827 0.02174377] [IC-Loss]: [0.0456543  0.0375061  0.02935791 0.02365112 0.01794434]
# [Batch]: 20 [ST-Loss]: [0.         0.00409222 0.00870132 0.01382732 0.01947021] [IC-Loss]: [0.0435791  0.03640747 0.02923584 0.02377319 0.01831055]
# [Batch]: 21 [ST-Loss]: [0.         0.00470257 0.00992966 0.01568127 0.0219574 ] [IC-Loss]: [0.04626465 0.03829956 0.03033447 0.02456665 0.01879883]
# [Batch]: 22 [ST-Loss]: [0.         0.00426769 0.00909042 0.01446819 0.020401  ] [IC-Loss]: [0.04870605 0.04071045 0.03271484 0.02679443 0.02087402]
# [Batch]: 23 [ST-Loss]: [0.         0.00413036 0.00886154 0.01419353 0.02012634] [IC-Loss]: [0.05285645 0.04351807 0.03417969 0.02679443 0.01940918]
# [Batch]: 24 [ST-Loss]: [0.         0.00474739 0.01010895 0.01608467 0.02267456] [IC-Loss]: [0.04626465 0.03869629 0.03112793 0.02563477 0.0201416 ]
# [Batch]: 25 [ST-Loss]: [0.         0.00375271 0.0080452  0.01287746 0.01824951] [IC-Loss]: [0.0456543  0.03753662 0.02941895 0.02307129 0.01672363]
# [Batch]: 26 [ST-Loss]: [0.         0.00445366 0.00937653 0.0147686  0.02062988] [IC-Loss]: [0.03930664 0.0333252  0.02734375 0.02325439 0.01916504]
# [Batch]: 27 [ST-Loss]: [0.         0.00359726 0.00765228 0.01216507 0.01713562] [IC-Loss]: [0.04760742 0.03918457 0.03076172 0.02380371 0.0168457 ]
# [Batch]: 28 [ST-Loss]: [0.         0.00485611 0.01024628 0.0161705  0.02262878] [IC-Loss]: [0.04589844 0.03872681 0.03155518 0.02645874 0.0213623 ]
# [Batch]: 29 [ST-Loss]: [0.         0.00443172 0.00936508 0.01480007 0.02073669] [IC-Loss]: [0.04321289 0.03594971 0.02868652 0.02319336 0.0177002 ]
# [Batch]: 30 [ST-Loss]: [0.         0.004076   0.00872803 0.01395607 0.01976013] [IC-Loss]: [0.04309082 0.0357666  0.02844238 0.02331543 0.01818848]
# [Batch]: 31 [ST-Loss]: [0.         0.00419331 0.00891495 0.01416492 0.01994324] [IC-Loss]: [0.046875   0.03933716 0.03179932 0.02590942 0.02001953]
# [Correlation] = 0.25
# 	[ST] = [0.0, 0.0042504072189331055, 0.009106636047363281, 0.014568686485290527, 0.020636558532714844],
# 	[IC] = [0.0473480224609375, 0.03927421569824219, 0.031200408935546875, 0.025194168090820312, 0.01918792724609375]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.00270844 0.00577545 0.00920105 0.01298523] [IC-Loss]: [0.02819824 0.02374268 0.01928711 0.01611328 0.01293945]
# [Batch]: 1 [ST-Loss]: [0.         0.00269985 0.00580978 0.0093298  0.01325989] [IC-Loss]: [0.02697754 0.02249146 0.01800537 0.0149231  0.01184082]
# [Batch]: 2 [ST-Loss]: [0.         0.0025053  0.00542831 0.00876904 0.01252747] [IC-Loss]: [0.03063965 0.02572632 0.02081299 0.01779175 0.01477051]
# [Batch]: 3 [ST-Loss]: [0.         0.00278759 0.00603104 0.00973034 0.0138855 ] [IC-Loss]: [0.02832031 0.02386475 0.01940918 0.01605225 0.01269531]
# [Batch]: 4 [ST-Loss]: [0.         0.00268459 0.00572586 0.0091238  0.01287842] [IC-Loss]: [0.02294922 0.02001953 0.01708984 0.01501465 0.01293945]
# [Batch]: 5 [ST-Loss]: [0.         0.00216103 0.00466919 0.00752449 0.01072693] [IC-Loss]: [0.02697754 0.02258301 0.01818848 0.01470947 0.01123047]
# [Batch]: 6 [ST-Loss]: [0.         0.00230885 0.00494766 0.00791645 0.01121521] [IC-Loss]: [0.02661133 0.02227783 0.01794434 0.01464844 0.01135254]
# [Batch]: 7 [ST-Loss]: [0.         0.00257969 0.0055275  0.00884342 0.01252747] [IC-Loss]: [0.02490234 0.02139282 0.0178833  0.01571655 0.0135498 ]
# [Batch]: 8 [ST-Loss]: [0.         0.00219727 0.00475311 0.00766754 0.01094055] [IC-Loss]: [0.03112793 0.0255127  0.01989746 0.01525879 0.01062012]
# [Batch]: 9 [ST-Loss]: [0.         0.00263882 0.00575638 0.00935268 0.01342773] [IC-Loss]: [0.02880859 0.02444458 0.02008057 0.01712036 0.01416016]
# [Batch]: 10 [ST-Loss]: [0.         0.00273895 0.00591278 0.00952148 0.01356506] [IC-Loss]: [0.02502441 0.02185059 0.01867676 0.01690674 0.01513672]
# [Batch]: 11 [ST-Loss]: [0.         0.00248718 0.00543976 0.00885773 0.01274109] [IC-Loss]: [0.03112793 0.02590942 0.02069092 0.01675415 0.01281738]
# [Batch]: 12 [ST-Loss]: [0.         0.00244904 0.00534821 0.00869751 0.01249695] [IC-Loss]: [0.02966309 0.02493286 0.02020264 0.01669312 0.01318359]
# [Batch]: 13 [ST-Loss]: [0.         0.00255108 0.00553513 0.00895214 0.01280212] [IC-Loss]: [0.02734375 0.02276611 0.01818848 0.01507568 0.01196289]
# [Batch]: 14 [ST-Loss]: [0.         0.00233936 0.00509262 0.00825977 0.01184082] [IC-Loss]: [0.02563477 0.02200317 0.01837158 0.01565552 0.01293945]
# [Batch]: 15 [ST-Loss]: [0.         0.00262547 0.00560379 0.00893497 0.01261902] [IC-Loss]: [0.02587891 0.02157593 0.01727295 0.0140686  0.01086426]
# [Batch]: 16 [ST-Loss]: [0.         0.00281525 0.00596619 0.00945282 0.01327515] [IC-Loss]: [0.02819824 0.02404785 0.01989746 0.01672363 0.0135498 ]
# [Batch]: 17 [ST-Loss]: [0.         0.00253868 0.00559998 0.00918388 0.01329041] [IC-Loss]: [0.03417969 0.02850342 0.02282715 0.01879883 0.01477051]
# [Batch]: 18 [ST-Loss]: [0.         0.00255203 0.00544739 0.00868607 0.01226807] [IC-Loss]: [0.03039551 0.02539062 0.02038574 0.0168457  0.01330566]
# [Batch]: 19 [ST-Loss]: [0.         0.00259113 0.00571823 0.00938129 0.01358032] [IC-Loss]: [0.02893066 0.02459717 0.02026367 0.01721191 0.01416016]
# [Batch]: 20 [ST-Loss]: [0.         0.00247765 0.00536346 0.00865746 0.01235962] [IC-Loss]: [0.03161621 0.02627563 0.02093506 0.01651001 0.01208496]
# [Batch]: 21 [ST-Loss]: [0.         0.00288105 0.00623703 0.01006794 0.01437378] [IC-Loss]: [0.02856445 0.02401733 0.01947021 0.01620483 0.01293945]
# [Batch]: 22 [ST-Loss]: [0.         0.0030117  0.00640869 0.01019096 0.01435852] [IC-Loss]: [0.02819824 0.02371216 0.01922607 0.01589966 0.01257324]
# [Batch]: 23 [ST-Loss]: [0.         0.00223923 0.00482941 0.00777054 0.01106262] [IC-Loss]: [0.02709961 0.02304077 0.01898193 0.01596069 0.01293945]
# [Batch]: 24 [ST-Loss]: [0.         0.00279713 0.00600052 0.00961018 0.0136261 ] [IC-Loss]: [0.02893066 0.02429199 0.01965332 0.01641846 0.01318359]
# [Batch]: 25 [ST-Loss]: [0.         0.00298595 0.00638199 0.0101881  0.0144043 ] [IC-Loss]: [0.03442383 0.02853394 0.02264404 0.01834106 0.01403809]
# [Batch]: 26 [ST-Loss]: [0.         0.00243282 0.00521469 0.0083456  0.01182556] [IC-Loss]: [0.02697754 0.02285767 0.01873779 0.01535034 0.01196289]
# [Batch]: 27 [ST-Loss]: [0.         0.00336838 0.00724792 0.01163864 0.01654053] [IC-Loss]: [0.03125    0.02627563 0.02130127 0.01834106 0.01538086]
# [Batch]: 28 [ST-Loss]: [0.         0.00293541 0.00630188 0.01009941 0.014328  ] [IC-Loss]: [0.02832031 0.02386475 0.01940918 0.01690674 0.0144043 ]
# [Batch]: 29 [ST-Loss]: [0.         0.00253963 0.00553513 0.00898647 0.01289368] [IC-Loss]: [0.0300293  0.02496338 0.01989746 0.01617432 0.01245117]
# [Batch]: 30 [ST-Loss]: [0.         0.00335598 0.00714493 0.01136684 0.01602173] [IC-Loss]: [0.03186035 0.02658081 0.02130127 0.01766968 0.01403809]
# [Batch]: 31 [ST-Loss]: [0.         0.00311565 0.00665665 0.01062298 0.01501465] [IC-Loss]: [0.02990723 0.025177   0.02044678 0.01748657 0.01452637]
# [Correlation] = 0.5
# 	[ST] = [0.0, 0.0026593804359436035, 0.0057315826416015625, 0.009216606616973877, 0.013114452362060547],
# 	[IC] = [0.028720855712890625, 0.024163246154785156, 0.019605636596679688, 0.01635456085205078, 0.013103485107421875]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.00093174 0.00205612 0.00337315 0.00488281] [IC-Loss]: [0.00976562 0.00836182 0.00695801 0.00628662 0.00561523]
# [Batch]: 1 [ST-Loss]: [0.         0.00104141 0.0022583  0.00365067 0.00521851] [IC-Loss]: [0.01123047 0.00961304 0.00799561 0.00686646 0.0057373 ]
# [Batch]: 2 [ST-Loss]: [0.         0.00087833 0.00193405 0.00316715 0.00457764] [IC-Loss]: [0.00830078 0.00717163 0.00604248 0.00521851 0.00439453]
# [Batch]: 3 [ST-Loss]: [0.         0.00088882 0.00191498 0.00307846 0.00437927] [IC-Loss]: [0.01184082 0.00961304 0.00738525 0.00564575 0.00390625]
# [Batch]: 4 [ST-Loss]: [0.         0.00106621 0.0022583  0.00357628 0.00502014] [IC-Loss]: [0.00842285 0.00735474 0.00628662 0.00570679 0.00512695]
# [Batch]: 5 [ST-Loss]: [0.         0.00094223 0.00204468 0.00330734 0.00473022] [IC-Loss]: [0.01025391 0.00881958 0.00738525 0.00656128 0.0057373 ]
# [Batch]: 6 [ST-Loss]: [0.         0.00093746 0.00198746 0.00314999 0.00442505] [IC-Loss]: [0.00585938 0.00540161 0.00494385 0.00460815 0.00427246]
# [Batch]: 7 [ST-Loss]: [0.         0.00095558 0.00203705 0.0032444  0.00457764] [IC-Loss]: [0.00671387 0.00592041 0.00512695 0.0045166  0.00390625]
# [Batch]: 8 [ST-Loss]: [0.         0.00083256 0.00183487 0.00300694 0.00434875] [IC-Loss]: [0.01123047 0.00924683 0.00726318 0.00570679 0.00415039]
# [Batch]: 9 [ST-Loss]: [0.         0.00075626 0.00163651 0.00264072 0.00376892] [IC-Loss]: [0.0078125  0.00665283 0.00549316 0.00457764 0.00366211]
# [Batch]: 10 [ST-Loss]: [0.         0.0007534  0.00165558 0.00270653 0.00390625] [IC-Loss]: [0.0090332  0.00759888 0.00616455 0.00497437 0.00378418]
# [Batch]: 11 [ST-Loss]: [0.         0.00105476 0.0022583  0.00361061 0.00511169] [IC-Loss]: [0.00598145 0.00558472 0.00518799 0.0050354  0.00488281]
# [Batch]: 12 [ST-Loss]: [0.         0.0012846  0.00283432 0.00464916 0.00672913] [IC-Loss]: [0.01062012 0.00942993 0.00823975 0.00759888 0.00695801]
# [Batch]: 13 [ST-Loss]: [0.         0.00098705 0.00214767 0.00348186 0.00498962] [IC-Loss]: [0.00744629 0.00674438 0.00604248 0.00576782 0.00549316]
# [Batch]: 14 [ST-Loss]: [0.         0.00094986 0.00210571 0.00346756 0.0050354 ] [IC-Loss]: [0.00964355 0.00839233 0.00714111 0.00631714 0.00549316]
# [Batch]: 15 [ST-Loss]: [0.         0.0006609  0.00143814 0.00233173 0.00334167] [IC-Loss]: [0.00878906 0.00744629 0.00610352 0.00488281 0.00366211]
# [Batch]: 16 [ST-Loss]: [0.         0.00124168 0.00271606 0.00442314 0.00636292] [IC-Loss]: [0.00830078 0.00759888 0.00689697 0.00656128 0.00622559]
# [Batch]: 17 [ST-Loss]: [0.         0.00086498 0.0018959  0.00309277 0.00445557] [IC-Loss]: [0.01000977 0.00842285 0.00683594 0.00610352 0.00537109]
# [Batch]: 18 [ST-Loss]: [0.         0.00057793 0.00126648 0.00206566 0.00297546] [IC-Loss]: [0.01000977 0.00808716 0.00616455 0.00460815 0.00305176]
# [Batch]: 19 [ST-Loss]: [0.         0.00094891 0.00204086 0.00327587 0.00465393] [IC-Loss]: [0.00878906 0.00775146 0.00671387 0.00616455 0.00561523]
# [Batch]: 20 [ST-Loss]: [0.         0.0008297  0.00184631 0.00304985 0.00444031] [IC-Loss]: [0.00805664 0.00698853 0.00592041 0.00521851 0.0045166 ]
# [Batch]: 21 [ST-Loss]: [0.         0.00094032 0.00205231 0.00333595 0.00479126] [IC-Loss]: [0.00720215 0.00643921 0.00567627 0.00534058 0.00500488]
# [Batch]: 22 [ST-Loss]: [0.         0.00095844 0.00208664 0.00338459 0.00485229] [IC-Loss]: [0.01062012 0.00894165 0.00726318 0.006073   0.00488281]
# [Batch]: 23 [ST-Loss]: [0.         0.00090981 0.00202942 0.00335884 0.00489807] [IC-Loss]: [0.0098877  0.00830078 0.00671387 0.0055542  0.00439453]
# [Batch]: 24 [ST-Loss]: [0.         0.00131512 0.00276566 0.00435162 0.006073  ] [IC-Loss]: [0.00769043 0.00695801 0.00622559 0.00567627 0.00512695]
# [Batch]: 25 [ST-Loss]: [0.         0.00125313 0.0026474  0.00418282 0.00585938] [IC-Loss]: [0.0078125  0.00671387 0.00561523 0.00500488 0.00439453]
# [Batch]: 26 [ST-Loss]: [0.         0.00073528 0.00159073 0.00256634 0.00366211] [IC-Loss]: [0.00744629 0.00674438 0.00604248 0.00552368 0.00500488]
# [Batch]: 27 [ST-Loss]: [0.         0.00117779 0.0025444  0.00409985 0.00584412] [IC-Loss]: [0.00708008 0.00637817 0.00567627 0.00540161 0.00512695]
# [Batch]: 28 [ST-Loss]: [0.         0.00086021 0.00189972 0.00311852 0.0045166 ] [IC-Loss]: [0.00842285 0.00726318 0.00610352 0.00549316 0.00488281]
# [Batch]: 29 [ST-Loss]: [0.         0.0010643  0.00222778 0.00349045 0.00485229] [IC-Loss]: [0.01025391 0.00827026 0.00628662 0.00460815 0.00292969]
# [Batch]: 30 [ST-Loss]: [0.         0.00073814 0.00160217 0.00259209 0.00370789] [IC-Loss]: [0.00854492 0.00704956 0.0055542  0.00448608 0.00341797]
# [Batch]: 31 [ST-Loss]: [0.         0.00093937 0.00204086 0.00330448 0.00473022] [IC-Loss]: [0.00720215 0.00656128 0.00592041 0.00582886 0.0057373 ]
# [Correlation] = 0.75
# 	[ST] = [0.0, 0.0009461343288421631, 0.002051711082458496, 0.003316730260848999, 0.004741191864013672],
# 	[IC] = [0.008758544921875, 0.007556915283203125, 0.00635528564453125, 0.0055599212646484375, 0.004764556884765625]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.02047499 0.04097588 0.06150267 0.08205536] [IC-Loss]: [5.31005859e-02 3.98254395e-02 2.65502930e-02 1.32751465e-02
#  2.20516557e-17]
# [Batch]: 1 [ST-Loss]: [0.         0.01940861 0.03919562 0.05936106 0.0799049 ] [IC-Loss]: [5.85937500e-02 4.39453125e-02 2.92968750e-02 1.46484375e-02
#  2.16662558e-17]
# [Batch]: 2 [ST-Loss]: [0.         0.01914636 0.0387271  0.05874223 0.07919174] [IC-Loss]: [5.61523438e-02 4.21142578e-02 2.80761719e-02 1.40380859e-02
#  2.24150329e-17]
# [Batch]: 3 [ST-Loss]: [0.         0.0202673  0.04085941 0.06177635 0.08301812] [IC-Loss]: [5.57861328e-02 4.18395996e-02 2.78930664e-02 1.39465332e-02
#  2.16984430e-17]
# [Batch]: 4 [ST-Loss]: [0.         0.01993831 0.04025712 0.06095645 0.08203628] [IC-Loss]: [4.87060547e-02 3.65295410e-02 2.43530273e-02 1.21765137e-02
#  2.20923133e-17]
# [Batch]: 5 [ST-Loss]: [0.         0.01920944 0.03881319 0.05881125 0.07920361] [IC-Loss]: [5.52978516e-02 4.14733887e-02 2.76489258e-02 1.38244629e-02
#  2.18949547e-17]
# [Batch]: 6 [ST-Loss]: [0.         0.02058831 0.04136494 0.0623299  0.08348319] [IC-Loss]: [5.45654297e-02 4.09240723e-02 2.72827148e-02 1.36413574e-02
#  2.20381032e-17]
# [Batch]: 7 [ST-Loss]: [0.         0.01974926 0.03984078 0.06027454 0.08105055] [IC-Loss]: [5.77392578e-02 4.33044434e-02 2.88696289e-02 1.44348145e-02
#  2.20702905e-17]
# [Batch]: 8 [ST-Loss]: [0.         0.02007782 0.04030752 0.06068909 0.08122253] [IC-Loss]: [5.21240234e-02 3.90930176e-02 2.60620117e-02 1.30310059e-02
#  2.19373063e-17]
# [Batch]: 9 [ST-Loss]: [0.         0.01935925 0.03904492 0.05905701 0.07939553] [IC-Loss]: [5.70068359e-02 4.27551270e-02 2.85034180e-02 1.42517090e-02
#  2.25353116e-17]
# [Batch]: 10 [ST-Loss]: [0.         0.01965639 0.03969053 0.06010242 0.08089206] [IC-Loss]: [5.33447266e-02 4.00085449e-02 2.66723633e-02 1.33361816e-02
#  2.15070136e-17]
# [Batch]: 11 [ST-Loss]: [0.         0.01996394 0.04006212 0.06029454 0.08066119] [IC-Loss]: [5.78613281e-02 4.33959961e-02 2.89306641e-02 1.44653320e-02
#  2.21431353e-17]
# [Batch]: 12 [ST-Loss]: [0.         0.02019091 0.04062539 0.06130345 0.08222508] [IC-Loss]: [6.14013672e-02 4.60510254e-02 3.07006836e-02 1.53503418e-02
#  2.19466237e-17]
# [Batch]: 13 [ST-Loss]: [0.         0.02029033 0.0409646  0.06202279 0.08346491] [IC-Loss]: [5.48095703e-02 4.11071777e-02 2.74047852e-02 1.37023926e-02
#  2.21532997e-17]
# [Batch]: 14 [ST-Loss]: [0.         0.01952307 0.0393197  0.05938989 0.07973364] [IC-Loss]: [5.61523438e-02 4.21142578e-02 2.80761719e-02 1.40380859e-02
#  2.16942078e-17]
# [Batch]: 15 [ST-Loss]: [0.         0.02011829 0.04047827 0.06107995 0.08192333] [IC-Loss]: [5.67626953e-02 4.25720215e-02 2.83813477e-02 1.41906738e-02
#  2.18686966e-17]
# [Batch]: 16 [ST-Loss]: [0.         0.02002059 0.04001213 0.05997463 0.07990808] [IC-Loss]: [5.76171875e-02 4.32128906e-02 2.88085938e-02 1.44042969e-02
#  2.27462228e-17]
# [Batch]: 17 [ST-Loss]: [0.         0.01940666 0.03932773 0.05976319 0.08071306] [IC-Loss]: [6.10351562e-02 4.57763672e-02 3.05175781e-02 1.52587891e-02
#  2.23726812e-17]
# [Batch]: 18 [ST-Loss]: [0.         0.02017995 0.04065752 0.06143272 0.08250554] [IC-Loss]: [5.34667969e-02 4.01000977e-02 2.67333984e-02 1.33666992e-02
#  2.27131885e-17]
# [Batch]: 19 [ST-Loss]: [0.         0.0203553  0.04099113 0.0619075  0.0831044 ] [IC-Loss]: [6.04248047e-02 4.53186035e-02 3.02124023e-02 1.51062012e-02
#  2.20109982e-17]
# [Batch]: 20 [ST-Loss]: [0.         0.01959286 0.03960492 0.06003615 0.08088658] [IC-Loss]: [5.23681641e-02 3.92761230e-02 2.61840820e-02 1.30920410e-02
#  2.26276382e-17]
# [Batch]: 21 [ST-Loss]: [0.         0.02034041 0.04069348 0.06105919 0.08143756] [IC-Loss]: [5.55419922e-02 4.16564941e-02 2.77709961e-02 1.38854980e-02
#  2.23794575e-17]
# [Batch]: 22 [ST-Loss]: [0.         0.02018996 0.04062033 0.06129111 0.0822023 ] [IC-Loss]: [5.26123047e-02 3.94592285e-02 2.63061523e-02 1.31530762e-02
#  2.20109982e-17]
# [Batch]: 23 [ST-Loss]: [0.         0.01927054 0.03897717 0.05911987 0.07969864] [IC-Loss]: [5.79833984e-02 4.34875488e-02 2.89916992e-02 1.44958496e-02
#  2.20372562e-17]
# [Batch]: 24 [ST-Loss]: [0.         0.02100296 0.04212107 0.06335433 0.08470273] [IC-Loss]: [6.03027344e-02 4.52270508e-02 3.01513672e-02 1.50756836e-02
#  2.21744755e-17]
# [Batch]: 25 [ST-Loss]: [0.         0.0204487  0.041064   0.06184591 0.08279443] [IC-Loss]: [5.81054688e-02 4.35791016e-02 2.90527344e-02 1.45263672e-02
#  2.27148825e-17]
# [Batch]: 26 [ST-Loss]: [0.         0.02024054 0.04077941 0.0616166  0.08275212] [IC-Loss]: [5.40771484e-02 4.05578613e-02 2.70385742e-02 1.35192871e-02
#  2.20609731e-17]
# [Batch]: 27 [ST-Loss]: [0.         0.01989053 0.03998972 0.06029756 0.08081407] [IC-Loss]: [5.72509766e-02 4.29382324e-02 2.86254883e-02 1.43127441e-02
#  2.15095547e-17]
# [Batch]: 28 [ST-Loss]: [0.         0.02021948 0.04070566 0.06145854 0.08247813] [IC-Loss]: [5.09033203e-02 3.81774902e-02 2.54516602e-02 1.27258301e-02
#  2.18017810e-17]
# [Batch]: 29 [ST-Loss]: [0.         0.02044131 0.04127255 0.06249371 0.0841048 ] [IC-Loss]: [6.11572266e-02 4.58679199e-02 3.05786133e-02 1.52893066e-02
#  2.17568883e-17]
# [Batch]: 30 [ST-Loss]: [0.         0.02006354 0.04045827 0.0611842  0.08224132] [IC-Loss]: [5.12695312e-02 3.84521484e-02 2.56347656e-02 1.28173828e-02
#  2.22244505e-17]
# [Batch]: 31 [ST-Loss]: [0.         0.02029656 0.040931   0.06190333 0.08321354] [IC-Loss]: [4.96826172e-02 3.72619629e-02 2.48413086e-02 1.24206543e-02
#  2.23362588e-17]
# [Correlation] = 0.0
# ...
#  2.33128878e-17]
# [Batch]: 6 [ST-Loss]: [0.         0.01909662 0.03868677 0.05877045 0.07934766] [IC-Loss]: [5.21240234e-02 3.90930176e-02 2.60620117e-02 1.30310059e-02
#  2.39422333e-17]
# [Batch]: 7 [ST-Loss]: [0.         0.01992511 0.04039505 0.06140985 0.08296948] [IC-Loss]: [4.33349609e-02 3.25012207e-02 2.16674805e-02 1.08337402e-02
#  2.27377524e-17]
# [Batch]: 8 [ST-Loss]: [0.         0.02153125 0.04363594 0.06631409 0.08956567] [IC-Loss]: [4.76074219e-02 3.57055664e-02 2.38037109e-02 1.19018555e-02
#  2.33891208e-17]
# [Batch]: 9 [ST-Loss]: [0.         0.02068815 0.04173158 0.06313027 0.08488425] [IC-Loss]: [4.74853516e-02 3.56140137e-02 2.37426758e-02 1.18713379e-02
#  2.27961977e-17]
# [Batch]: 10 [ST-Loss]: [0.         0.02152727 0.0433762  0.0655468  0.08803905] [IC-Loss]: [4.96826172e-02 3.72619629e-02 2.48413086e-02 1.24206543e-02
#  2.34975410e-17]
# [Batch]: 11 [ST-Loss]: [0.         0.02147536 0.04322231 0.06524083 0.08753093] [IC-Loss]: [4.38232422e-02 3.28674316e-02 2.19116211e-02 1.09558105e-02
#  2.34704359e-17]
# [Batch]: 12 [ST-Loss]: [0.         0.02025836 0.04100008 0.06222518 0.08393364] [IC-Loss]: [5.10253906e-02 3.82690430e-02 2.55126953e-02 1.27563477e-02
#  2.33484632e-17]
# [Batch]: 13 [ST-Loss]: [0.         0.02050876 0.04147273 0.0628919  0.08476628] [IC-Loss]: [4.41894531e-02 3.31420898e-02 2.20947266e-02 1.10473633e-02
#  2.39371511e-17]
# [Batch]: 14 [ST-Loss]: [0.         0.02044638 0.04142318 0.06293039 0.08496801] [IC-Loss]: [5.06591797e-02 3.79943848e-02 2.53295898e-02 1.26647949e-02
#  2.29664513e-17]
# [Batch]: 15 [ST-Loss]: [0.         0.02052061 0.04154746 0.06308056 0.08511991] [IC-Loss]: [5.10253906e-02 3.82690430e-02 2.55126953e-02 1.27563477e-02
#  2.36271370e-17]
# [Batch]: 16 [ST-Loss]: [0.         0.0213805  0.04309559 0.06514525 0.0875295 ] [IC-Loss]: [4.51660156e-02 3.38745117e-02 2.25830078e-02 1.12915039e-02
#  2.29393463e-17]
# [Batch]: 17 [ST-Loss]: [0.         0.02099608 0.04224452 0.06374533 0.08549852] [IC-Loss]: [4.57763672e-02 3.43322754e-02 2.28881836e-02 1.14440918e-02
#  2.33162759e-17]
# [Batch]: 18 [ST-Loss]: [0.         0.02045752 0.04137713 0.06275883 0.08460262] [IC-Loss]: [5.05371094e-02 3.79028320e-02 2.52685547e-02 1.26342773e-02
#  2.34526482e-17]
# [Batch]: 19 [ST-Loss]: [0.         0.02198517 0.04421726 0.06669627 0.0894222 ] [IC-Loss]: [4.62646484e-02 3.46984863e-02 2.31323242e-02 1.15661621e-02
#  2.31926091e-17]
# [Batch]: 20 [ST-Loss]: [0.         0.02023374 0.04101827 0.06235361 0.08423975] [IC-Loss]: [4.63867188e-02 3.47900391e-02 2.31933594e-02 1.15966797e-02
#  2.29740746e-17]
# [Batch]: 21 [ST-Loss]: [0.         0.0218865  0.04422281 0.06700893 0.09024485] [IC-Loss]: [4.41894531e-02 3.31420898e-02 2.20947266e-02 1.10473633e-02
#  2.28182206e-17]
# [Batch]: 22 [ST-Loss]: [0.         0.02067395 0.04155397 0.06264006 0.08393221] [IC-Loss]: [5.11474609e-02 3.83605957e-02 2.55737305e-02 1.27868652e-02
#  2.28377023e-17]
# [Batch]: 23 [ST-Loss]: [0.         0.02078093 0.04186842 0.06326245 0.08496303] [IC-Loss]: [4.94384766e-02 3.70788574e-02 2.47192383e-02 1.23596191e-02
#  2.31892210e-17]
# [Batch]: 24 [ST-Loss]: [0.         0.02116181 0.04250213 0.06402098 0.08571834] [IC-Loss]: [4.39453125e-02 3.29589844e-02 2.19726563e-02 1.09863281e-02
#  2.35068584e-17]
# [Batch]: 25 [ST-Loss]: [0.         0.02072787 0.0418949  0.06350109 0.08554644] [IC-Loss]: [4.84619141e-02 3.63464355e-02 2.42309570e-02 1.21154785e-02
#  2.35974909e-17]
# [Batch]: 26 [ST-Loss]: [0.         0.02083362 0.04208298 0.06374808 0.08582891] [IC-Loss]: [4.67529297e-02 3.50646973e-02 2.33764648e-02 1.16882324e-02
#  2.23167771e-17]
# [Batch]: 27 [ST-Loss]: [0.         0.02094419 0.0423342  0.06417003 0.08645169] [IC-Loss]: [5.23681641e-02 3.92761230e-02 2.61840820e-02 1.30920410e-02
#  2.26505080e-17]
# [Batch]: 28 [ST-Loss]: [0.         0.02019928 0.04075044 0.06165348 0.08290839] [IC-Loss]: [4.38232422e-02 3.28674316e-02 2.19116211e-02 1.09558105e-02
#  2.28114443e-17]
# [Batch]: 29 [ST-Loss]: [0.         0.02071357 0.04184152 0.06338385 0.08534055] [IC-Loss]: [4.40673828e-02 3.30505371e-02 2.20336914e-02 1.10168457e-02
#  2.25793573e-17]
# [Batch]: 30 [ST-Loss]: [0.         0.0216249  0.04349237 0.06560242 0.08795505] [IC-Loss]: [5.07812500e-02 3.80859375e-02 2.53906250e-02 1.26953125e-02
#  2.31045177e-17]
# [Batch]: 31 [ST-Loss]: [0.         0.02117164 0.04269373 0.06456627 0.08678926] [IC-Loss]: [5.29785156e-02 3.97338867e-02 2.64892578e-02 1.32446289e-02
#  2.37372513e-17]
# [Correlation] = 0.25
# 	[ST] = [0.0, 0.020762119493964643, 0.04193025351398521, 0.0635044020600617, 0.08548456513219409],
# 	[IC] = [0.047374725341796875, 0.03553104400634766, 0.023687362670898448, 0.011843681335449219, 2.321243499369167e-17]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.02151726 0.0441328  0.06784663 0.09265873] [IC-Loss]: [3.51562500e-02 2.63671875e-02 1.75781250e-02 8.78906250e-03
#  2.45902135e-17]
# [Batch]: 1 [ST-Loss]: [0.         0.02272842 0.04646071 0.07119685 0.09693686] [IC-Loss]: [2.91748047e-02 2.18811035e-02 1.45874023e-02 7.29370117e-03
#  2.50213533e-17]
# [Batch]: 2 [ST-Loss]: [0.         0.02312125 0.0471947  0.07222034 0.09819818] [IC-Loss]: [2.52685547e-02 1.89514160e-02 1.26342773e-02 6.31713867e-03
#  2.51492552e-17]
# [Batch]: 3 [ST-Loss]: [0.         0.02203325 0.04525994 0.06968006 0.09529363] [IC-Loss]: [3.22265625e-02 2.41699219e-02 1.61132813e-02 8.05664062e-03
#  2.49976363e-17]
# [Batch]: 4 [ST-Loss]: [0.         0.02383977 0.04864809 0.07442498 0.10117043] [IC-Loss]: [2.45361328e-02 1.84020996e-02 1.22680664e-02 6.13403320e-03
#  2.50111889e-17]
# [Batch]: 5 [ST-Loss]: [0.         0.02341288 0.04755283 0.07241984 0.0980139 ] [IC-Loss]: [2.99072266e-02 2.24304199e-02 1.49536133e-02 7.47680664e-03
#  2.58785506e-17]
# [Batch]: 6 [ST-Loss]: [0.         0.02215753 0.04534282 0.06955589 0.09479674] [IC-Loss]: [3.02734375e-02 2.27050781e-02 1.51367188e-02 7.56835938e-03
#  2.50137300e-17]
# [Batch]: 7 [ST-Loss]: [0.         0.0219014  0.04516741 0.06979804 0.09579327] [IC-Loss]: [3.16162109e-02 2.37121582e-02 1.58081055e-02 7.90405273e-03
#  2.41997313e-17]
# [Batch]: 8 [ST-Loss]: [0.         0.02318525 0.04728665 0.0723042  0.09823791] [IC-Loss]: [2.72216797e-02 2.04162598e-02 1.36108398e-02 6.80541992e-03
#  2.43911607e-17]
# [Batch]: 9 [ST-Loss]: [0.         0.02235726 0.04581243 0.0703655  0.09601649] [IC-Loss]: [2.96630859e-02 2.22473145e-02 1.48315430e-02 7.41577148e-03
#  2.43208570e-17]
# [Batch]: 10 [ST-Loss]: [0.         0.02294364 0.04693788 0.07198271 0.09807814] [IC-Loss]: [2.63671875e-02 1.97753906e-02 1.31835938e-02 6.59179688e-03
#  2.45190627e-17]
# [Batch]: 11 [ST-Loss]: [0.         0.02378585 0.04866322 0.07463211 0.10169252] [IC-Loss]: [2.67333984e-02 2.00500488e-02 1.33666992e-02 6.68334961e-03
#  2.41395920e-17]
# [Batch]: 12 [ST-Loss]: [0.         0.02228802 0.04556059 0.06981771 0.09505937] [IC-Loss]: [2.49023438e-02 1.86767578e-02 1.24511719e-02 6.22558594e-03
#  2.47028689e-17]
# [Batch]: 13 [ST-Loss]: [0.         0.02330566 0.0476815  0.07312754 0.09964376] [IC-Loss]: [2.69775391e-02 2.02331543e-02 1.34887695e-02 6.74438477e-03
#  2.42310715e-17]
# [Batch]: 14 [ST-Loss]: [0.         0.02239868 0.04584555 0.0703406  0.09588385] [IC-Loss]: [2.49023438e-02 1.86767578e-02 1.24511719e-02 6.22558594e-03
#  2.47816429e-17]
# [Batch]: 15 [ST-Loss]: [0.         0.02363562 0.04820822 0.0737178  0.10016436] [IC-Loss]: [2.52685547e-02 1.89514160e-02 1.26342773e-02 6.31713867e-03
#  2.49569788e-17]
# [Batch]: 16 [ST-Loss]: [0.         0.02238824 0.04571223 0.06997196 0.09516745] [IC-Loss]: [2.66113281e-02 1.99584961e-02 1.33056641e-02 6.65283203e-03
#  2.48231476e-17]
# [Batch]: 17 [ST-Loss]: [0.         0.02381792 0.04860299 0.07435521 0.10107459] [IC-Loss]: [2.69775391e-02 2.02331543e-02 1.34887695e-02 6.74438477e-03
#  2.53305203e-17]
# [Batch]: 18 [ST-Loss]: [0.         0.02183583 0.04481611 0.06894085 0.09421004] [IC-Loss]: [2.78320312e-02 2.08740234e-02 1.39160156e-02 6.95800781e-03
#  2.54567282e-17]
# [Batch]: 19 [ST-Loss]: [0.         0.02262919 0.04633683 0.07112293 0.09698749] [IC-Loss]: [2.88085938e-02 2.16064453e-02 1.44042969e-02 7.20214844e-03
#  2.49857779e-17]
# [Batch]: 20 [ST-Loss]: [0.         0.02277358 0.046552   0.07133526 0.09712336] [IC-Loss]: [2.85644531e-02 2.14233398e-02 1.42822266e-02 7.14111328e-03
#  2.42759643e-17]
# [Batch]: 21 [ST-Loss]: [0.         0.02244963 0.04601852 0.07070667 0.09651407] [IC-Loss]: [2.39257812e-02 1.79443359e-02 1.19628906e-02 5.98144531e-03
#  2.47477616e-17]
# [Batch]: 22 [ST-Loss]: [0.         0.02176857 0.04468028 0.06873512 0.09393311] [IC-Loss]: [2.72216797e-02 2.04162598e-02 1.36108398e-02 6.80541992e-03
#  2.45859783e-17]
# [Batch]: 23 [ST-Loss]: [0.         0.02261182 0.04609983 0.07046404 0.09570445] [IC-Loss]: [2.44140625e-02 1.83105469e-02 1.22070313e-02 6.10351562e-03
#  2.49358029e-17]
# [Batch]: 24 [ST-Loss]: [0.         0.02382137 0.04860408 0.07434812 0.1010535 ] [IC-Loss]: [2.49023438e-02 1.86767578e-02 1.24511719e-02 6.22558594e-03
#  2.45902135e-17]
# [Batch]: 25 [ST-Loss]: [0.         0.02268261 0.04641161 0.071187   0.09700878] [IC-Loss]: [3.12500000e-02 2.34375000e-02 1.56250000e-02 7.81250000e-03
#  2.53432258e-17]
# [Batch]: 26 [ST-Loss]: [0.         0.0237254  0.04816712 0.07332516 0.09919951] [IC-Loss]: [2.94189453e-02 2.20642090e-02 1.47094727e-02 7.35473633e-03
#  2.44419827e-17]
# [Batch]: 27 [ST-Loss]: [0.         0.02269508 0.04648024 0.07135548 0.0973208 ] [IC-Loss]: [2.75878906e-02 2.06909180e-02 1.37939453e-02 6.89697266e-03
#  2.48849810e-17]
# [Batch]: 28 [ST-Loss]: [0.         0.02175275 0.04454737 0.06838387 0.09326225] [IC-Loss]: [2.91748047e-02 2.18811035e-02 1.45874023e-02 7.29370117e-03
#  2.44496060e-17]
# [Batch]: 29 [ST-Loss]: [0.         0.02308268 0.04692978 0.07154131 0.09691726] [IC-Loss]: [2.51464844e-02 1.88598633e-02 1.25732422e-02 6.28662109e-03
#  2.48239946e-17]
# [Batch]: 30 [ST-Loss]: [0.         0.02171667 0.04470885 0.06897657 0.0945198 ] [IC-Loss]: [2.58789062e-02 1.94091797e-02 1.29394531e-02 6.46972656e-03
#  2.52500522e-17]
# [Batch]: 31 [ST-Loss]: [0.         0.02482466 0.05009888 0.07582268 0.10199605] [IC-Loss]: [2.52685547e-02 1.89514160e-02 1.26342773e-02 6.31713867e-03
#  2.52314174e-17]
# [Correlation] = 0.5
# 	[ST] = [0.0, 0.02278711657143302, 0.04657881499992477, 0.07137509528547525, 0.09717595742808448],
# 	[IC] = [0.027599334716796875, 0.02069950103759766, 0.013799667358398451, 0.006899833679199219, 2.4814438994745567e-17]
#
#
# [Batch]: 0 [ST-Loss]: [0.         0.02715142 0.05612751 0.08692828 0.11955372] [IC-Loss]: [1.00097656e-02 7.50732422e-03 5.00488281e-03 2.50244141e-03
#  2.10225107e-17]
# [Batch]: 1 [ST-Loss]: [0.         0.02583135 0.05387008 0.08411618 0.11656965] [IC-Loss]: [1.02539062e-02 7.69042969e-03 5.12695313e-03 2.56347656e-03
#  1.94961573e-17]
# [Batch]: 2 [ST-Loss]: [0.         0.02594158 0.05411676 0.08452554 0.11716792] [IC-Loss]: [9.64355469e-03 7.23266602e-03 4.82177734e-03 2.41088867e-03
#  1.97324795e-17]
# [Batch]: 3 [ST-Loss]: [0.         0.02664062 0.05531585 0.08602567 0.1187701 ] [IC-Loss]: [8.30078125e-03 6.22558594e-03 4.15039063e-03 2.07519531e-03
#  2.02525578e-17]
# [Batch]: 4 [ST-Loss]: [0.         0.02622584 0.0543869  0.08448319 0.11651471] [IC-Loss]: [9.88769531e-03 7.41577148e-03 4.94384766e-03 2.47192383e-03
#  1.97333266e-17]
# [Batch]: 5 [ST-Loss]: [0.         0.02595528 0.05438805 0.08529831 0.11868607] [IC-Loss]: [9.15527344e-03 6.86645508e-03 4.57763672e-03 2.28881836e-03
#  1.87685560e-17]
# [Batch]: 6 [ST-Loss]: [0.         0.02645166 0.0551411  0.08606833 0.11923334] [IC-Loss]: [8.30078125e-03 6.22558594e-03 4.15039063e-03 2.07519531e-03
#  1.84712475e-17]
# [Batch]: 7 [ST-Loss]: [0.         0.02634753 0.05481454 0.08540104 0.11810703] [IC-Loss]: [8.17871094e-03 6.13403320e-03 4.08935547e-03 2.04467773e-03
#  2.02508637e-17]
# [Batch]: 8 [ST-Loss]: [0.         0.02674782 0.05548237 0.08620365 0.11891166] [IC-Loss]: [9.64355469e-03 7.23266602e-03 4.82177734e-03 2.41088867e-03
#  1.94724404e-17]
# [Batch]: 9 [ST-Loss]: [0.         0.02641392 0.05473265 0.0849562  0.11708456] [IC-Loss]: [8.42285156e-03 6.31713867e-03 4.21142578e-03 2.10571289e-03
#  1.95232624e-17]
# [Batch]: 10 [ST-Loss]: [0.         0.02679266 0.05563978 0.08654138 0.11949746] [IC-Loss]: [9.39941406e-03 7.04956055e-03 4.69970703e-03 2.34985352e-03
#  1.94402532e-17]
# [Batch]: 11 [ST-Loss]: [0.         0.02664687 0.05501913 0.08511679 0.11693984] [IC-Loss]: [1.15966797e-02 8.69750977e-03 5.79833984e-03 2.89916992e-03
#  2.09081613e-17]
# [Batch]: 12 [ST-Loss]: [0.         0.02724516 0.05643445 0.08756788 0.12064544] [IC-Loss]: [8.78906250e-03 6.59179688e-03 4.39453125e-03 2.19726562e-03
#  1.88871407e-17]
# [Batch]: 13 [ST-Loss]: [0.         0.02540604 0.05302175 0.08284712 0.11488215] [IC-Loss]: [9.64355469e-03 7.23266602e-03 4.82177734e-03 2.41088867e-03
#  2.04355169e-17]
# [Batch]: 14 [ST-Loss]: [0.         0.02695693 0.05591734 0.08688121 0.11984854] [IC-Loss]: [9.76562500e-03 7.32421875e-03 4.88281250e-03 2.44140625e-03
#  1.90988989e-17]
# [Batch]: 15 [ST-Loss]: [0.         0.02603338 0.05412413 0.08427224 0.1164777 ] [IC-Loss]: [6.83593750e-03 5.12695313e-03 3.41796875e-03 1.70898438e-03
#  1.93589380e-17]
# [Batch]: 16 [ST-Loss]: [0.         0.02658345 0.05510273 0.08555783 0.11794877] [IC-Loss]: [7.81250000e-03 5.85937500e-03 3.90625000e-03 1.95312500e-03
#  1.93140453e-17]
# [Batch]: 17 [ST-Loss]: [0.         0.02727481 0.05653781 0.08778898 0.12102834] [IC-Loss]: [8.54492188e-03 6.40869141e-03 4.27246094e-03 2.13623047e-03
#  2.00484228e-17]
# [Batch]: 18 [ST-Loss]: [0.         0.02677024 0.05562196 0.08655515 0.11956983] [IC-Loss]: [8.54492188e-03 6.40869141e-03 4.27246094e-03 2.13623047e-03
#  2.02610281e-17]
# [Batch]: 19 [ST-Loss]: [0.         0.0269351  0.05572095 0.08635755 0.11884491] [IC-Loss]: [8.66699219e-03 6.50024414e-03 4.33349609e-03 2.16674805e-03
#  1.98188769e-17]
# [Batch]: 20 [ST-Loss]: [0.         0.02533778 0.0527201  0.08214694 0.11361832] [IC-Loss]: [8.17871094e-03 6.13403320e-03 4.08935547e-03 2.04467773e-03
#  1.99645666e-17]
# [Batch]: 21 [ST-Loss]: [0.         0.02567765 0.05323207 0.08266327 0.11397123] [IC-Loss]: [9.39941406e-03 7.04956055e-03 4.69970703e-03 2.34985352e-03
#  2.10402984e-17]
# [Batch]: 22 [ST-Loss]: [0.         0.02624551 0.05474218 0.08548999 0.11848895] [IC-Loss]: [6.83593750e-03 5.12695313e-03 3.41796875e-03 1.70898438e-03
#  2.01238088e-17]
# [Batch]: 23 [ST-Loss]: [0.         0.02529622 0.05271376 0.08225261 0.11391277] [IC-Loss]: [1.01318359e-02 7.59887695e-03 5.06591797e-03 2.53295898e-03
#  1.94292417e-17]
# [Batch]: 24 [ST-Loss]: [0.         0.02736747 0.05644781 0.08724102 0.11974711] [IC-Loss]: [9.03320312e-03 6.77490234e-03 4.51660156e-03 2.25830078e-03
#  2.03542017e-17]
# [Batch]: 25 [ST-Loss]: [0.         0.02500097 0.05219334 0.08157711 0.11315227] [IC-Loss]: [9.64355469e-03 7.23266602e-03 4.82177734e-03 2.41088867e-03
#  2.04804096e-17]
# [Batch]: 26 [ST-Loss]: [0.         0.02577909 0.05365339 0.08362292 0.11568766] [IC-Loss]: [9.64355469e-03 7.23266602e-03 4.82177734e-03 2.41088867e-03
#  2.01924184e-17]
# [Batch]: 27 [ST-Loss]: [0.         0.02618984 0.05440312 0.08463985 0.11690002] [IC-Loss]: [7.81250000e-03 5.85937500e-03 3.90625000e-03 1.95312500e-03
#  1.97231622e-17]
# [Batch]: 28 [ST-Loss]: [0.         0.02515761 0.05264888 0.08247378 0.11463234] [IC-Loss]: [8.05664062e-03 6.04248047e-03 4.02832031e-03 2.01416016e-03
#  2.02593340e-17]
# [Batch]: 29 [ST-Loss]: [0.         0.02630989 0.05474952 0.08531886 0.11801794] [IC-Loss]: [1.12304688e-02 8.42285156e-03 5.61523438e-03 2.80761719e-03
#  1.92098602e-17]
# [Batch]: 30 [ST-Loss]: [0.         0.02672083 0.05554034 0.08645855 0.11947544] [IC-Loss]: [8.78906250e-03 6.59179688e-03 4.39453125e-03 2.19726562e-03
#  1.89066224e-17]
# [Batch]: 31 [ST-Loss]: [0.         0.02638378 0.05481395 0.08529051 0.11781345] [IC-Loss]: [7.81250000e-03 5.85937500e-03 3.90625000e-03 1.95312500e-03
#  1.93496206e-17]
# [Correlation] = 0.75
# 	[ST] = [0.0, 0.026306822068161435, 0.054667946365144514, 0.08508337289094925, 0.11755310164557561],
# 	[IC] = [0.008998870849609375, 0.006749153137207035, 0.004499435424804706, 0.0022497177124023438, 1.9791507147747965e-17]

# %% [markdown]
# # Computing Welfares

# %%
def compute_welfare(mech, corr):
    VAL_WF = 0.0
    data_generator = Data(num_agents = num_agents, prob = prob, corr = corr)
    
    for j in range(num_validation_batches):
        P, Q = data_generator.generate_batch(batch_size)
        R = mech(P, Q)
        VAL_WF += (P*R + Q*R).sum()/(batch_size * num_agents * 2)
    VAL_WF = VAL_WF/num_validation_batches
    
    return VAL_WF

# %%
RSD_WF_corrs = []
TTC_WF_corrs = []
DA_WF_corrs = []

corr_values = [0.0, 0.25, 0.50, 0.75]

for corr in corr_values:
    RSD_WF = max(compute_welfare(compute_one_RSD_batch, corr), compute_welfare(compute_one_RSD_batch_switch, corr))
    RSD_WF_corrs.append(RSD_WF)
    
    TTC_WF = max(compute_welfare(compute_TTC_batch, corr), compute_welfare(compute_TTC_batch_switch, corr))
    TTC_WF_corrs.append(TTC_WF)
    
    DA_WF  = max(compute_welfare(compute_DA_batch, corr), compute_welfare(compute_DA_batch_switch, corr))
    DA_WF_corrs.append(DA_WF)
    
    
print("RSD Welfare for different correlation values =", RSD_WF_corrs)

print("TTC Welfare for different correlation values =", TTC_WF_corrs)

print("DA Welfare for different correlation values =", DA_WF_corrs)

welfare_data = {"RSD_One_WF_corrs" : RSD_WF_corrs, "TTC_WF_corrs" : TTC_WF_corrs, "DA_WF_corrs" : DA_WF_corrs}
# Out:
# RSD Welfare for different correlation values = [0.5901008844375609, 0.5809719165166218, 0.5583945115407307, 0.520987590154012]
# TTC Welfare for different correlation values = [0.6249351501464844, 0.6191310882568359, 0.595860481262207, 0.5509366989135742]
# DA Welfare for different correlation values = [0.6407747268676758, 0.6324958801269531, 0.6059226989746094, 0.5572671890258789]

# %%
data_to_save = {
    'ST_scores': ST_scores,
    'IC_scores': IC_scores,
    'combination_ST': combination_ST,
    'combination_IC': combination_IC,
    'welfare_data': welfare_data
}

with open('output_classical.pkl', 'wb') as f:
    pickle.dump(data_to_save, f)

# %%
with open('output_classical.pkl', 'rb') as f:
    loaded_data = pickle.load(f)

ST_scores = loaded_data['ST_scores']
IC_scores = loaded_data['IC_scores']
combination_ST = loaded_data['combination_ST']
combination_IC = loaded_data['combination_IC']
welfare_data = loaded_data['welfare_data']

print(ST_scores)
print("")
print(IC_scores)
print("")
print(combination_ST)
print("")
print(combination_IC)
print("")
print(welfare_data)
# Out:
# {'DA_ST': [0.0, 0.0, 0.0, 0.0], 'TTC_ST': [0.02318286895751953, 0.020354270935058594, 0.013127803802490234, 0.0046062469482421875], 'RSD_One_ST': [0.08183395365873973, 0.08539383278952706, 0.09741250177224477, 0.11894305050373077]}
#
# {'DA_IC': [0.05620574951171875, 0.04791259765625, 0.0283966064453125, 0.0091094970703125], 'TTC_IC': [0.0206146240234375, 0.0189971923828125, 0.01351165771484375, 0.004886627197265625], 'RSD_One_IC': [2.2114547945152087e-17, 2.3372630099841138e-17, 2.4766316935429683e-17, 1.9797859894852372e-17]}
#
# {'RSD_One_TTC_ST': [[0.023557662963867188, 0.03660981067352825, 0.050596503747834115, 0.06551774218678474, 0.08137352599038017], [0.01992940902709961, 0.034820513696306295, 0.05072699694169893, 0.06764885876327753, 0.08558609916104211], [0.01295614242553711, 0.03229603290350901, 0.05290001113381651, 0.07476807711645961, 0.09790023085143833], [0.0047550201416015625, 0.02972915385746293, 0.05682480790548854, 0.08604198228567839, 0.11738067699803245]], 'TTC_DA_ST': [[0.0, 0.004774570465087891, 0.010175704956054688, 0.01620340347290039, 0.022857666015625], [0.0, 0.0042504072189331055, 0.009106636047363281, 0.014568686485290527, 0.020636558532714844], [0.0, 0.0026593804359436035, 0.0057315826416015625, 0.009216606616973877, 0.013114452362060547], [0.0, 0.0009461343288421631, 0.002051711082458496, 0.003316730260848999, 0.004741191864013672]], 'RSD_One_DA_ST': [[0.0, 0.019997576924247876, 0.04027291159662937, 0.06082600401714444, 0.08165685418579313], [0.0, 0.020762119493964643, 0.04193025351398521, 0.0635044020600617, 0.08548456513219409], [0.0, 0.02278711657143302, 0.04657881499992477, 0.07137509528547525, 0.09717595742808448], [0.0, 0.026306822068161435, 0.054667946365144514, 0.08508337289094925, 0.11755310164557561]]}
#
# {'RSD_One_TTC_IC': [[0.021404266357421875, 0.016053199768066417, 0.010702133178710957, 0.005351066589355469, 2.205689676517959e-17], [0.018596649169921875, 0.013947486877441418, 0.00929832458496096, 0.004649162292480469, 2.3271859648897478e-17], [0.01314544677734375, 0.009859085083007818, 0.006572723388671902, 0.0032863616943359375, 2.4686669368608177e-17], [0.00518798828125, 0.003890991210937506, 0.0025939941406250186, 0.0012969970703125, 1.9737747025376918e-17]], 'TTC_DA_IC': [[0.055866241455078125, 0.04592132568359375, 0.035976409912109375, 0.028242111206054688, 0.0205078125], [0.0473480224609375, 0.03927421569824219, 0.031200408935546875, 0.025194168090820312, 0.01918792724609375], [0.028720855712890625, 0.024163246154785156, 0.019605636596679688, 0.01635456085205078, 0.013103485107421875], [0.008758544921875, 0.007556915283203125, 0.00635528564453125, 0.0055599212646484375, 0.004764556884765625]], 'RSD_One_DA_IC': [[0.05572509765625, 0.04179382324218751, 0.027862548828125007, 0.0139312744140625, 2.2099698398795535e-17], [0.047374725341796875, 0.03553104400634766, 0.023687362670898448, 0.011843681335449219, 2.321243499369167e-17], [0.027599334716796875, 0.02069950103759766, 0.013799667358398451, 0.006899833679199219, 2.4814438994745567e-17], [0.008998870849609375, 0.006749153137207035, 0.004499435424804706, 0.0022497177124023438, 1.9791507147747965e-17]]}
#
# {'RSD_One_WF_corrs': [0.5901008844375609, 0.5809719165166218, 0.5583945115407307, 0.520987590154012], 'TTC_WF_corrs': [0.6249351501464844, 0.6191310882568359, 0.595860481262207, 0.5509366989135742], 'DA_WF_corrs': [0.6407747268676758, 0.6324958801269531, 0.6059226989746094, 0.5572671890258789]}
